# %%
from __future__ import division
import os, time
import numpy as np
import glob
import torch
import torch.nn as nn
import torch.nn.functional as F
import random
import sys
from optparse import OptionParser
import numpy as np
from torch import optim
from PIL import Image
from torch.autograd import Function, Variable
import matplotlib.pyplot as plt
from torchvision import transforms
from torch.utils.data import Dataset
# import cv2
import pickle
from tqdm import tqdm
import rawpy
# %matplotlib inline

input_dir = './Dataset/Sony/short/'
gt_dir = './Dataset/Sony/long/'

result_dir = './results_SSIM/'
model_save_path = './results_SSIM/net_weights/'
if os.path.isdir(model_save_path) is not True:
    os.makedirs(model_save_path, exist_ok=True)

# %%
if torch.cuda.is_available():
    deviceTag = torch.device('cuda')
else:
    deviceTag = torch.device('cpu')
print(deviceTag)
# Out:
# cuda

# %%
from pytorch_msssim import ssim, ms_ssim, SSIM, MS_SSIM

# %% [markdown]
# # LOAD DATASET

# %%
# get train IDs
train_fns = glob.glob(gt_dir + '0*.ARW')
train_ids = [int(os.path.basename(train_fn)[0:5]) for train_fn in train_fns]

ps = 512  # patch size for training
save_freq = 500

DEBUG = 0
if DEBUG == 1:
    save_freq = 2
    train_ids = train_ids[0:5]

# %% [markdown]
# # UNET MODULES

# %%
class conv_lrelu(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(conv_lrelu, self).__init__()
        self.conv = nn.Sequential(nn.Conv2d(in_ch,out_ch,3, padding = 1),nn.LeakyReLU())

    def forward(self, x):
        x = self.conv(x)
        return x
    
class down(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(down, self).__init__()
        self.conv1 = conv_lrelu(in_ch,out_ch)
        self.conv2 = conv_lrelu(out_ch,out_ch)
        self.down =  nn.MaxPool2d((2,2))
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.down(x)
        return x
    

class up(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(up, self).__init__()       
        self.up =  nn.UpsamplingBilinear2d(scale_factor = 2)
        self.conv1 = conv_lrelu(in_ch,out_ch) 
        self.conv2 = conv_lrelu(out_ch,out_ch) 

    def forward(self, x1, x2):
        x1 = self.up(x1)
        x = torch.cat([x2, x1], dim=1)
        x = self.conv1(x)
        x = self.conv2(x)
        return x

class UNet(nn.Module):
    def __init__(self, in_ch = 4, CH_PER_SCALE = [32,64,128,256,512], out_ch = 12):
        super(UNet, self).__init__()
        self.inc = conv_lrelu(in_ch, CH_PER_SCALE[0])
        self.inc2 = conv_lrelu(CH_PER_SCALE[0], CH_PER_SCALE[0])
        self.down1 = down(CH_PER_SCALE[0], CH_PER_SCALE[1]) 
        self.down2 = down(CH_PER_SCALE[1],CH_PER_SCALE[2])
        self.down3 = down(CH_PER_SCALE[2],CH_PER_SCALE[3])                
        self.down4 = down(CH_PER_SCALE[3],CH_PER_SCALE[4])                
        self.up1 = up(CH_PER_SCALE[4]+CH_PER_SCALE[3],CH_PER_SCALE[3])
        self.up2 = up(CH_PER_SCALE[3]+CH_PER_SCALE[2],CH_PER_SCALE[2])
        self.up3 = up(CH_PER_SCALE[2]+CH_PER_SCALE[1],CH_PER_SCALE[1])
        self.up4 = up(CH_PER_SCALE[1]+CH_PER_SCALE[0],CH_PER_SCALE[0])
        self.outc = nn.Conv2d(CH_PER_SCALE[0], out_ch, 1, padding = 0)

    def forward(self, x):
        x0 = self.inc(x)
        x0 = self.inc2(x0)
        x1 = self.down1(x0)
        x2 = self.down2(x1)
        x3 = self.down3(x2)
        x4 = self.down4(x3)
        x3_up = self.up1(x4,x3)
        x2_up = self.up2(x3_up,x2)
        x1_up = self.up3(x2_up,x1)
        out = self.up4(x1_up,x0)
        out = self.outc(out)
#         out = F.pixel_shuffle(out,2) ## Paper final step rearranges 12 channes to 3 RGB channels
#         out = F.hardtanh(out, min_val=0, max_val=1) #Clamp the top and bottom to 0,1 since pixels can only be in this value
        return out
    
class PRIDNet(nn.Module):
    def __init__(self, in_ch = 4, out_ch = 12):
        super(PRIDNet, self).__init__()
        self.feature_extraction = nn.Sequential(conv_lrelu(in_ch, 32), *[conv_lrelu(32, 32) for i in range(3)])
        self.unet0 = UNet(in_ch = 32, out_ch = 12)
        self.unet1 = UNet(in_ch = 32, out_ch = 12)
        self.unet2 = UNet(in_ch = 32, out_ch = 12)
        self.unet3 = UNet(in_ch = 32, out_ch = 12)
        self.unet4 = UNet(in_ch = 32, out_ch = 12)
        self.avgpool1 = nn.AvgPool2d((2,2))
        self.avgpool2 = nn.AvgPool2d((4,4))
        self.avgpool3 = nn.AvgPool2d((8,8))
        self.avgpool4 = nn.AvgPool2d((16,16))
        self.up4 =  nn.UpsamplingBilinear2d(scale_factor = 16)
        self.up3 =  nn.UpsamplingBilinear2d(scale_factor = 8)
        self.up2 =  nn.UpsamplingBilinear2d(scale_factor = 4)
        self.up1 =  nn.UpsamplingBilinear2d(scale_factor = 2)
        self.out =  nn.Conv2d(32+12*5, out_ch, 1, padding = 0)

    def forward(self, x):
        x_feat = self.feature_extraction(x)
        x0 = self.unet0(x_feat)
        x1 = self.up1(self.unet1(self.avgpool1(x_feat)))
        x2 = self.up2(self.unet2(self.avgpool2(x_feat)))
        x3 = self.up3(self.unet3(self.avgpool3(x_feat)))
        x4 = self.up4(self.unet4(self.avgpool4(x_feat)))
        x_unet_all = torch.cat([x_feat,x0,x1,x2,x3,x4], axis = 1)
        out = self.out(x_unet_all)
        
        out = F.pixel_shuffle(out,2) ## Paper final step rearranges 12 channes to 3 RGB channels
        out = F.hardtanh(out, min_val=0, max_val=1) #Clamp the top and bottom to 0,1 since pixels can only be in this value
        return out
    
    def load_my_state_dict(self, state_dict):
        own_state = self.state_dict()
        for name, param in state_dict.items():
            if name not in own_state:
                 continue
            #if isinstance(param, self.Parameter):
            else:
                # backwards compatibility for serialized parameters
                param = param.data
            own_state[name].copy_(param)

# %% [markdown]
# # Helper Functions for packing raw and saving images

# %%
def pack_raw(raw):
    # pack Bayer image to 4 channels
    im = raw.raw_image_visible.astype(np.float32)
    im = np.maximum(im - 512, 0) / (16383 - 512)  # subtract the black level

    im = np.expand_dims(im, axis=2)
    img_shape = im.shape
    H = img_shape[0]
    W = img_shape[1]

    out = np.concatenate((im[0:H:2, 0:W:2, :],
                          im[0:H:2, 1:W:2, :],
                          im[1:H:2, 1:W:2, :],
                          im[1:H:2, 0:W:2, :]), axis=2)
    return out

# %%
# Raw data takes long time to load. Keep them in memory after loaded.
gt_images = [None] * 6000
input_images = {}
input_images['300'] = [None] * len(train_ids)
input_images['250'] = [None] * len(train_ids)
input_images['100'] = [None] * len(train_ids)

g_loss = np.zeros((5000, 1))

allfolders = glob.glob(result_dir + '*0')

for folder in allfolders:
    lastepoch = np.maximum(epochs, int(folder[-4:]))

# %% [markdown]
# # Training

# %%
def process_img(input_raw_img, model, ratio):
    ## Process image(s) using the given model
    # input_raw_img: numpy array, dimension: (Batch,Height,Width,Channel)
    # ratio: numpy array, dimension: (Batch,)
    model.eval();
    model.to(deviceTag)
    ratio = ratio.reshape(ratio.shape[0],1,1,1)
    input_raw_img = np.transpose(input_raw_img, [0,3,1,2]).astype('float32')*ratio
    input_tensor = torch.from_numpy(input_raw_img.copy()).float().to(deviceTag)
    with torch.no_grad():
        output_tensor = model(input_tensor)
    output_img = output_tensor.cpu().numpy()
    output_img = np.transpose(output_img, [0,2,3,1])
    
    return output_img
    
def validate(model, input_list, gt_list, block_size = None, batch_size = 8):
    assert len(input_list) == len(gt_list)
    
    model.eval();
    PSNR_list = []
    
    for i in range(len(input_list)//batch_size):
        if i%10 == 0:
            print(i)
        input_raw_img_batch = []
        gt_img_batch = []
        ratio_batch = []
        for b in range(batch_size):
            if i*batch_size+b < len(input_list):
                in_path = input_list[i*batch_size+b]
                gt_path = gt_list[i*batch_size+b]
            else:
                break
            in_fn = os.path.basename(in_path)
            gt_fn = os.path.basename(gt_path)
            in_exposure = float(in_fn[9:-5])
            gt_exposure = float(gt_fn[9:-5])
            ratio = min(gt_exposure / in_exposure, 300)
        
            raw = rawpy.imread(in_path)
            input_raw_img = pack_raw(raw)
            
            gt_raw = rawpy.imread(gt_path)
            gt_img = gt_raw.postprocess(use_camera_wb=True, half_size=False, no_auto_bright=True, output_bps=16)
            gt_img = np.float32(gt_img / 65535.0)
            
            if block_size is not None:
                i_cut, j_cut = np.random.randint(0,input_raw_img.shape[0]-block_size), np.random.randint(0,input_raw_img.shape[1]-block_size)
                gt_img = gt_img[i_cut*2:i_cut*2+block_size*2, j_cut*2:j_cut*2+block_size*2, :]
                input_raw_img = input_raw_img[i_cut:i_cut+block_size, j_cut:j_cut+block_size, :]
            
            ratio_batch.append(ratio)
            input_raw_img_batch.append(input_raw_img)
            gt_img_batch.append(gt_img)
        
        input_raw_img_batch = np.array(input_raw_img_batch)
        ratio_batch = np.array(ratio_batch)
        gt_img_batch = np.array(gt_img_batch)
        
        output_img_batch = process_img(input_raw_img_batch, model, ratio_batch)
        plt.figure()
        plt.imshow(gt_img_batch[0,:,:,:])
        plt.title("Ground Truth")
        plt.figure()
        plt.imshow(output_img_batch[0,:,:,:])
        plt.title("Predicted patch")
        MSE = np.mean((output_img_batch.reshape(output_img_batch.shape[0],-1) - gt_img_batch.reshape(gt_img_batch.shape[0],-1))**2, axis = 1)
        PSNR_batch = 10*np.log10(1/MSE)
        PSNR_list.append(list(PSNR_batch))
    
    Val_PSNR = np.mean(PSNR_list)
        
    return Val_PSNR

# %%
model = PRIDNet()
model = model.cuda()
model = model.train()

# %%
learning_rate = 1e-4 
batch_num = 4
optimizer = optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=2000, gamma=0.1) #Step Scheduler. 
criterion = SSIM(data_range=1, size_average=True, channel=3)
Start_epoch = 0
epochs = 4000
TrainingLossData = np.zeros(epochs)

for epoch in range(Start_epoch, Start_epoch+epochs):
    print('Starting epoch {}/{}.'.format(epoch + 1, epochs))
    epoch_loss = 0 ## Set Epoch Loss
    count = 0;
    batches_processed = 0
    ##This version has a batch size of 1. In the future conside increasing batchsize
    for ind in np.random.permutation(len(train_ids)):    
        # get the path from image id
        train_id = train_ids[ind]
        in_files = glob.glob(input_dir + '%05d_00*.ARW' % train_id)
        in_path = in_files[np.random.random_integers(0, len(in_files) - 1)]
        in_fn = os.path.basename(in_path)

        gt_files = glob.glob(gt_dir + '%05d_00*.ARW' % train_id)
        gt_path = gt_files[0]
        gt_fn = os.path.basename(gt_path)
        in_exposure = float(in_fn[9:-5])
        gt_exposure = float(gt_fn[9:-5])
        ratio = min(gt_exposure / in_exposure, 300)

        st = time.time()

        if input_images[str(ratio)[0:3]][ind] is None:
            raw = rawpy.imread(in_path)
            input_images[str(ratio)[0:3]][ind] = np.expand_dims(pack_raw(raw), axis=0) * ratio

            gt_raw = rawpy.imread(gt_path)
            im = gt_raw.postprocess(use_camera_wb=True, half_size=False, no_auto_bright=True, output_bps=16)
            gt_images[ind] = np.expand_dims(np.float32(im / 65535.0), axis=0)

        # crop
        H = input_images[str(ratio)[0:3]][ind].shape[1]
        W = input_images[str(ratio)[0:3]][ind].shape[2]

        xx = np.random.randint(0, W - ps)
        yy = np.random.randint(0, H - ps)
        input_patch = input_images[str(ratio)[0:3]][ind][:, yy:yy + ps, xx:xx + ps, :]
        gt_patch = gt_images[ind][:, yy * 2:yy * 2 + ps * 2, xx * 2:xx * 2 + ps * 2, :]

        if np.random.randint(2, size=1)[0] == 1:  # random flip
            input_patch = np.flip(input_patch, axis=1)
            gt_patch = np.flip(gt_patch, axis=1)
        if np.random.randint(2, size=1)[0] == 1:
            input_patch = np.flip(input_patch, axis=2)
            gt_patch = np.flip(gt_patch, axis=2)
        if np.random.randint(2, size=1)[0] == 1:  # random transpose
            input_patch = np.transpose(input_patch, (0, 2, 1, 3))
            gt_patch = np.transpose(gt_patch, (0, 2, 1, 3))
        #(1, 512, 512, 4)
        #(1, 1024, 1024, 3)
        input_patch = np.transpose(input_patch, (0,3,1,2))
        input_patch = torch.from_numpy(input_patch.copy()).cuda()
        gt_patch = np.transpose(gt_patch, (0,3,1,2))
        gt_patch = torch.from_numpy(gt_patch.copy()).cuda()
        ##Batch concatenation
        if count%(batch_num)==0:
            input_patch_all = input_patch
            gt_patch_all = gt_patch
        else:
            input_patch_all = torch.cat([input_patch_all, input_patch], dim=0)
            gt_patch_all = torch.cat([gt_patch_all, gt_patch], dim=0)
        ##Every N batches we ship it back 
        if count%(batch_num)==batch_num-1:
            #print(input_patch_all.shape)
            img_pred = model.forward(input_patch_all)
            loss = 1 - criterion(img_pred, gt_patch_all)
            epoch_loss += loss.item()
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            batches_processed += 1
        count = count +1
    scheduler.step()
    print('Epoch finished ! Loss: {}'.format(epoch_loss / batches_processed))
    if epoch == 0:
        trainF= open(result_dir+"TrainingEpoch.txt","w+")
        trainF.write('Epoch,Train_loss\n')
        trainF.write('{},{}\n'.format(epoch, epoch_loss / batches_processed))
        trainF.close()
    else:
        trainF= open(result_dir+"TrainingEpoch.txt","a")
        trainF.write('{},{}\n'.format(epoch, epoch_loss / batches_processed))
        trainF.close()
    TrainingLossData[epoch] = epoch_loss / batches_processed ## Save for plotting
    ################################################ [TODO] ###################################################
    # Perform validation with eval_net() on the validation data
    # Save the model after every 10 epochs. This save our Memory on HPC.
    ##Save Top results after 95%
    if epoch > epochs*0.95:
        torch.save(model.state_dict(),model_save_path + 'sony{}.pth'.format(epoch + 1))
    if epoch%200 == 0:
        torch.save(model.state_dict(),model_save_path + 'sony{}.pth'.format(epoch + 1))
# Out:
# Starting epoch 1/4000.
# <ipython-input-10-d3612b83f9ad>:20: DeprecationWarning: This function is deprecated. Please call randint(0, 0 + 1) instead
#   in_path = in_files[np.random.random_integers(0, len(in_files) - 1)]
# <ipython-input-10-d3612b83f9ad>:20: DeprecationWarning: This function is deprecated. Please call randint(0, 2 + 1) instead
#   in_path = in_files[np.random.random_integers(0, len(in_files) - 1)]
# <ipython-input-10-d3612b83f9ad>:20: DeprecationWarning: This function is deprecated. Please call randint(0, 1 + 1) instead
#   in_path = in_files[np.random.random_integers(0, len(in_files) - 1)]
# Epoch finished ! Loss: 0.7763022989034652
# Starting epoch 2/4000.
# Epoch finished ! Loss: 0.6982577428221702
# Starting epoch 3/4000.
# Epoch finished ! Loss: 0.6785474762320518
# Starting epoch 4/4000.
# Epoch finished ! Loss: 0.5824663564562798
# Starting epoch 5/4000.
# Epoch finished ! Loss: 0.5399887874722481
# Starting epoch 6/4000.
# Epoch finished ! Loss: 0.5064837828278541
# Starting epoch 7/4000.
# Epoch finished ! Loss: 0.49664628356695173
# Starting epoch 8/4000.
# Epoch finished ! Loss: 0.4947374314069748
# Starting epoch 9/4000.
# Epoch finished ! Loss: 0.4861320167779922
# Starting epoch 10/4000.
# Epoch finished ! Loss: 0.479812479019165
# Starting epoch 11/4000.
# Epoch finished ! Loss: 0.46261010468006136
# Starting epoch 12/4000.
# Epoch finished ! Loss: 0.3993742436170578
# Starting epoch 13/4000.
# Epoch finished ! Loss: 0.3443560630083084
# Starting epoch 14/4000.
# Epoch finished ! Loss: 0.33322286456823347
# Starting epoch 15/4000.
# Epoch finished ! Loss: 0.3272545367479324
# Starting epoch 16/4000.
# Epoch finished ! Loss: 0.3175528973340988
# Starting epoch 17/4000.
# Epoch finished ! Loss: 0.3247975006699562
# Starting epoch 18/4000.
# Epoch finished ! Loss: 0.303954541683197
# Starting epoch 19/4000.
# Epoch finished ! Loss: 0.31453131437301635
# Starting epoch 20/4000.
# Epoch finished ! Loss: 0.31147550195455553
# Starting epoch 21/4000.
# Epoch finished ! Loss: 0.3097573101520538
# Starting epoch 22/4000.
# Epoch finished ! Loss: 0.312240406870842
# Starting epoch 23/4000.
# Epoch finished ! Loss: 0.3150433287024498
# Starting epoch 24/4000.
# Epoch finished ! Loss: 0.3082579761743546
# Starting epoch 25/4000.
# Epoch finished ! Loss: 0.29746133983135226
# Starting epoch 26/4000.
# Epoch finished ! Loss: 0.307849557697773
# Starting epoch 27/4000.
# Epoch finished ! Loss: 0.30447901487350465
# Starting epoch 28/4000.
# Epoch finished ! Loss: 0.30214022397994994
# Starting epoch 29/4000.
# Epoch finished ! Loss: 0.3073967397212982
# Starting epoch 30/4000.
# Epoch finished ! Loss: 0.30736598670482634
# Starting epoch 31/4000.
# Epoch finished ! Loss: 0.30612863749265673
# Starting epoch 32/4000.
# Epoch finished ! Loss: 0.2966527670621872
# Starting epoch 33/4000.
# Epoch finished ! Loss: 0.29119897335767747
# Starting epoch 34/4000.
# Epoch finished ! Loss: 0.306718048453331
# Starting epoch 35/4000.
# Epoch finished ! Loss: 0.299887977540493
# Starting epoch 36/4000.
# Epoch finished ! Loss: 0.31240352988243103
# Starting epoch 37/4000.
# Epoch finished ! Loss: 0.2995546251535416
# Starting epoch 38/4000.
# Epoch finished ! Loss: 0.3054358199238777
# Starting epoch 39/4000.
# Epoch finished ! Loss: 0.302694508433342
# Starting epoch 40/4000.
# Epoch finished ! Loss: 0.3008403807878494
# Starting epoch 41/4000.
# Epoch finished ! Loss: 0.2935501843690872
# Starting epoch 42/4000.
# Epoch finished ! Loss: 0.3066807761788368
# Starting epoch 43/4000.
# Epoch finished ! Loss: 0.3030719503760338
# Starting epoch 44/4000.
# Epoch finished ! Loss: 0.30090234577655794
# Starting epoch 45/4000.
# Epoch finished ! Loss: 0.29686217904090884
# Starting epoch 46/4000.
# Epoch finished ! Loss: 0.30187241584062574
# Starting epoch 47/4000.
# Epoch finished ! Loss: 0.2960881978273392
# Starting epoch 48/4000.
# Epoch finished ! Loss: 0.29452774077653887
# Starting epoch 49/4000.
# Epoch finished ! Loss: 0.29660201966762545
# Starting epoch 50/4000.
# Epoch finished ! Loss: 0.2881389781832695
# Starting epoch 51/4000.
# Epoch finished ! Loss: 0.2868896067142487
# Starting epoch 52/4000.
# Epoch finished ! Loss: 0.29384503811597823
# Starting epoch 53/4000.
# Epoch finished ! Loss: 0.2906388431787491
# Starting epoch 54/4000.
# Epoch finished ! Loss: 0.2842347890138626
# Starting epoch 55/4000.
# Epoch finished ! Loss: 0.2931591972708702
# Starting epoch 56/4000.
# Epoch finished ! Loss: 0.28743862807750703
# Starting epoch 57/4000.
# Epoch finished ! Loss: 0.29232715368270873
# Starting epoch 58/4000.
# Epoch finished ! Loss: 0.28698975741863253
# Starting epoch 59/4000.
# Epoch finished ! Loss: 0.28015155643224715
# Starting epoch 60/4000.
# Epoch finished ! Loss: 0.2833088517189026
# Starting epoch 61/4000.
# Epoch finished ! Loss: 0.28582467436790465
# Starting epoch 62/4000.
# Epoch finished ! Loss: 0.280483840405941
# Starting epoch 63/4000.
# Epoch finished ! Loss: 0.27404401153326036
# Starting epoch 64/4000.
# Epoch finished ! Loss: 0.27971468716859815
# Starting epoch 65/4000.
# Epoch finished ! Loss: 0.2692375183105469
# Starting epoch 66/4000.
# Epoch finished ! Loss: 0.2681947320699692
# Starting epoch 67/4000.
# Epoch finished ! Loss: 0.28794230818748473
# Starting epoch 68/4000.
# Epoch finished ! Loss: 0.2788413047790527
# Starting epoch 69/4000.
# Epoch finished ! Loss: 0.2761932283639908
# Starting epoch 70/4000.
# Epoch finished ! Loss: 0.2764298811554909
# Starting epoch 71/4000.
# Epoch finished ! Loss: 0.2640617832541466
# Starting epoch 72/4000.
# Epoch finished ! Loss: 0.27033309638500214
# Starting epoch 73/4000.
# Epoch finished ! Loss: 0.2860934168100357
# Starting epoch 74/4000.
# Epoch finished ! Loss: 0.26696215718984606
# Starting epoch 75/4000.
# Epoch finished ! Loss: 0.27512586414813994
# Starting epoch 76/4000.
# Epoch finished ! Loss: 0.2737061679363251
# Starting epoch 77/4000.
# Epoch finished ! Loss: 0.27489934414625167
# Starting epoch 78/4000.
# Epoch finished ! Loss: 0.26372231990098954
# Starting epoch 79/4000.
# Epoch finished ! Loss: 0.2640836998820305
# Starting epoch 80/4000.
# Epoch finished ! Loss: 0.273876728117466
# Starting epoch 81/4000.
# Epoch finished ! Loss: 0.2708280473947525
# Starting epoch 82/4000.
# Epoch finished ! Loss: 0.2695778399705887
# Starting epoch 83/4000.
# Epoch finished ! Loss: 0.26623097956180575
# Starting epoch 84/4000.
# Epoch finished ! Loss: 0.2725575968623161
# Starting epoch 85/4000.
# Epoch finished ! Loss: 0.27303260415792463
# Starting epoch 86/4000.
# Epoch finished ! Loss: 0.2700213402509689
# Starting epoch 87/4000.
# Epoch finished ! Loss: 0.27586780339479444
# Starting epoch 88/4000.
# Epoch finished ! Loss: 0.26074604839086535
# Starting epoch 89/4000.
# Epoch finished ! Loss: 0.25947385728359224
# Starting epoch 90/4000.
# Epoch finished ! Loss: 0.25914800316095354
# Starting epoch 91/4000.
# Epoch finished ! Loss: 0.2595059543848038
# Starting epoch 92/4000.
# Epoch finished ! Loss: 0.2677390664815903
# Starting epoch 93/4000.
# Epoch finished ! Loss: 0.256109219789505
# Starting epoch 94/4000.
# Epoch finished ! Loss: 0.2628470242023468
# Starting epoch 95/4000.
# Epoch finished ! Loss: 0.25593948662281035
# Starting epoch 96/4000.
# Epoch finished ! Loss: 0.26616190969944
# Starting epoch 97/4000.
# Epoch finished ! Loss: 0.2650270566344261
# Starting epoch 98/4000.
# Epoch finished ! Loss: 0.26451772153377534
# Starting epoch 99/4000.
# Epoch finished ! Loss: 0.25627187788486483
# Starting epoch 100/4000.
# Epoch finished ! Loss: 0.2571707621216774
# Starting epoch 101/4000.
# Epoch finished ! Loss: 0.26670063138008115
# Starting epoch 102/4000.
# Epoch finished ! Loss: 0.25425111055374144
# Starting epoch 103/4000.
# Epoch finished ! Loss: 0.26419262439012525
# Starting epoch 104/4000.
# Epoch finished ! Loss: 0.2649134799838066
# Starting epoch 105/4000.
# Epoch finished ! Loss: 0.25520685166120527
# Starting epoch 106/4000.
# Epoch finished ! Loss: 0.25626557469367983
# Starting epoch 107/4000.
# Epoch finished ! Loss: 0.2529133394360542
# Starting epoch 108/4000.
# Epoch finished ! Loss: 0.25870803743600845
# Starting epoch 109/4000.
# Epoch finished ! Loss: 0.26297643333673476
# Starting epoch 110/4000.
# Epoch finished ! Loss: 0.2610642105340958
# Starting epoch 111/4000.
# Epoch finished ! Loss: 0.2560896396636963
# Starting epoch 112/4000.
# Epoch finished ! Loss: 0.26181782931089403
# Starting epoch 113/4000.
# Epoch finished ! Loss: 0.2654600337147713
# Starting epoch 114/4000.
# Epoch finished ! Loss: 0.25260871201753615
# Starting epoch 115/4000.
# Epoch finished ! Loss: 0.262843719124794
# Starting epoch 116/4000.
# Epoch finished ! Loss: 0.2492108479142189
# Starting epoch 117/4000.
# Epoch finished ! Loss: 0.25028379410505297
# Starting epoch 118/4000.
# Epoch finished ! Loss: 0.2556744381785393
# Starting epoch 119/4000.
# Epoch finished ! Loss: 0.26103105694055556
# Starting epoch 120/4000.
# Epoch finished ! Loss: 0.2572656229138374
# Starting epoch 121/4000.
# Epoch finished ! Loss: 0.25234428644180296
# Starting epoch 122/4000.
# Epoch finished ! Loss: 0.2525854170322418
# Starting epoch 123/4000.
# Epoch finished ! Loss: 0.2542822942137718
# Starting epoch 124/4000.
# Epoch finished ! Loss: 0.25371196419000625
# Starting epoch 125/4000.
# Epoch finished ! Loss: 0.2541937053203583
# Starting epoch 126/4000.
# Epoch finished ! Loss: 0.26231185495853426
# Starting epoch 127/4000.
# Epoch finished ! Loss: 0.2538023337721825
# Starting epoch 128/4000.
# Epoch finished ! Loss: 0.23885460644960405
# Starting epoch 129/4000.
# Epoch finished ! Loss: 0.24495213776826857
# Starting epoch 130/4000.
# Epoch finished ! Loss: 0.2516783058643341
# Starting epoch 131/4000.
# Epoch finished ! Loss: 0.2500741809606552
# Starting epoch 132/4000.
# Epoch finished ! Loss: 0.2493017092347145
# Starting epoch 133/4000.
# Epoch finished ! Loss: 0.2501416191458702
# Starting epoch 134/4000.
# Epoch finished ! Loss: 0.2551036819815636
# Starting epoch 135/4000.
# Epoch finished ! Loss: 0.25447954684495927
# Starting epoch 136/4000.
# Epoch finished ! Loss: 0.25209175050258636
# Starting epoch 137/4000.
# Epoch finished ! Loss: 0.25378765612840654
# Starting epoch 138/4000.
# Epoch finished ! Loss: 0.25054737031459806
# Starting epoch 139/4000.
# Epoch finished ! Loss: 0.25461516678333285
# Starting epoch 140/4000.
# Epoch finished ! Loss: 0.25481474548578265
# Starting epoch 141/4000.
# Epoch finished ! Loss: 0.24542183578014373
# Starting epoch 142/4000.
# Epoch finished ! Loss: 0.2532029449939728
# Starting epoch 143/4000.
# Epoch finished ! Loss: 0.25000740587711334
# Starting epoch 144/4000.
# Epoch finished ! Loss: 0.25144669115543367
# Starting epoch 145/4000.
# Epoch finished ! Loss: 0.2547737032175064
# Starting epoch 146/4000.
# Epoch finished ! Loss: 0.24730417430400847
# Starting epoch 147/4000.
# Epoch finished ! Loss: 0.24415889680385588
# Starting epoch 148/4000.
# Epoch finished ! Loss: 0.24394194036722183
# Starting epoch 149/4000.
# Epoch finished ! Loss: 0.24935422092676163
# Starting epoch 150/4000.
# Epoch finished ! Loss: 0.2518539145588875
# Starting epoch 151/4000.
# Epoch finished ! Loss: 0.24474403262138367
# Starting epoch 152/4000.
# Epoch finished ! Loss: 0.24816520065069197
# Starting epoch 153/4000.
# Epoch finished ! Loss: 0.2476666361093521
# Starting epoch 154/4000.
# Epoch finished ! Loss: 0.24577798545360566
# Starting epoch 155/4000.
# Epoch finished ! Loss: 0.24101664125919342
# Starting epoch 156/4000.
# Epoch finished ! Loss: 0.24938834458589554
# Starting epoch 157/4000.
# Epoch finished ! Loss: 0.24092466086149217
# Starting epoch 158/4000.
# Epoch finished ! Loss: 0.24615933001041412
# Starting epoch 159/4000.
# Epoch finished ! Loss: 0.2507416009902954
# Starting epoch 160/4000.
# Epoch finished ! Loss: 0.24523022770881653
# Starting epoch 161/4000.
# Epoch finished ! Loss: 0.245950323343277
# Starting epoch 162/4000.
# Epoch finished ! Loss: 0.24159670919179915
# Starting epoch 163/4000.
# Epoch finished ! Loss: 0.25136279314756393
# Starting epoch 164/4000.
# Epoch finished ! Loss: 0.2477595865726471
# Starting epoch 165/4000.
# Epoch finished ! Loss: 0.24441864043474198
# Starting epoch 166/4000.
# Epoch finished ! Loss: 0.24316504150629042
# Starting epoch 167/4000.
# Epoch finished ! Loss: 0.24507759660482406
# Starting epoch 168/4000.
# Epoch finished ! Loss: 0.24508943557739257
# Starting epoch 169/4000.
# Epoch finished ! Loss: 0.24047009348869325
# Starting epoch 170/4000.
# Epoch finished ! Loss: 0.2398625284433365
# Starting epoch 171/4000.
# Epoch finished ! Loss: 0.2484857052564621
# Starting epoch 172/4000.
# Epoch finished ! Loss: 0.2409254029393196
# Starting epoch 173/4000.
# Epoch finished ! Loss: 0.2303595259785652
# Starting epoch 174/4000.
# Epoch finished ! Loss: 0.24401158541440965
# Starting epoch 175/4000.
# Epoch finished ! Loss: 0.2502706602215767
# Starting epoch 176/4000.
# Epoch finished ! Loss: 0.244141086935997
# Starting epoch 177/4000.
# Epoch finished ! Loss: 0.25092567354440687
# Starting epoch 178/4000.
# Epoch finished ! Loss: 0.2359711930155754
# Starting epoch 179/4000.
# Epoch finished ! Loss: 0.2473979890346527
# Starting epoch 180/4000.
# Epoch finished ! Loss: 0.24171314239501954
# Starting epoch 181/4000.
# Epoch finished ! Loss: 0.241815447807312
# Starting epoch 182/4000.
# Epoch finished ! Loss: 0.2396460860967636
# Starting epoch 183/4000.
# Epoch finished ! Loss: 0.24797301292419432
# Starting epoch 184/4000.
# Epoch finished ! Loss: 0.245802541077137
# Starting epoch 185/4000.
# Epoch finished ! Loss: 0.2427340492606163
# Starting epoch 186/4000.
# Epoch finished ! Loss: 0.24439789801836015
# Starting epoch 187/4000.
# Epoch finished ! Loss: 0.24370892941951752
# Starting epoch 188/4000.
# Epoch finished ! Loss: 0.23758959025144577
# Starting epoch 189/4000.
# Epoch finished ! Loss: 0.24091997593641282
# Starting epoch 190/4000.
# Epoch finished ! Loss: 0.23767094165086747
# Starting epoch 191/4000.
# Epoch finished ! Loss: 0.23845296651124953
# Starting epoch 192/4000.
# Epoch finished ! Loss: 0.24439551830291747
# Starting epoch 193/4000.
# Epoch finished ! Loss: 0.2367761477828026
# Starting epoch 194/4000.
# Epoch finished ! Loss: 0.24116745889186858
# Starting epoch 195/4000.
# Epoch finished ! Loss: 0.23801880776882173
# Starting epoch 196/4000.
# Epoch finished ! Loss: 0.23866856396198272
# Starting epoch 197/4000.
# Epoch finished ! Loss: 0.2372108742594719
# Starting epoch 198/4000.
# Epoch finished ! Loss: 0.2398375853896141
# Starting epoch 199/4000.
# Epoch finished ! Loss: 0.23553194105625153
# Starting epoch 200/4000.
# Epoch finished ! Loss: 0.23391443341970444
# Starting epoch 201/4000.
# Epoch finished ! Loss: 0.2391187846660614
# Starting epoch 202/4000.
# Epoch finished ! Loss: 0.24327144175767898
# Starting epoch 203/4000.
# Epoch finished ! Loss: 0.24317298829555511
# Starting epoch 204/4000.
# Epoch finished ! Loss: 0.2531121805310249
# Starting epoch 205/4000.
# Epoch finished ! Loss: 0.2342675358057022
# Starting epoch 206/4000.
# Epoch finished ! Loss: 0.23136646151542664
# Starting epoch 207/4000.
# Epoch finished ! Loss: 0.2370214730501175
# Starting epoch 208/4000.
# Epoch finished ! Loss: 0.23851611614227294
# Starting epoch 209/4000.
# Epoch finished ! Loss: 0.24073255360126494
# Starting epoch 210/4000.
# Epoch finished ! Loss: 0.24055261313915252
# Starting epoch 211/4000.
# Epoch finished ! Loss: 0.23729980736970901
# Starting epoch 212/4000.
# Epoch finished ! Loss: 0.234382826089859
# Starting epoch 213/4000.
# Epoch finished ! Loss: 0.24311245530843734
# Starting epoch 214/4000.
# Epoch finished ! Loss: 0.24523821622133254
# Starting epoch 215/4000.
# Epoch finished ! Loss: 0.24688315987586976
# Starting epoch 216/4000.
# Epoch finished ! Loss: 0.24407500624656678
# Starting epoch 217/4000.
# Epoch finished ! Loss: 0.24877275079488753
# Starting epoch 218/4000.
# Epoch finished ! Loss: 0.23580225855112075
# Starting epoch 219/4000.
# Epoch finished ! Loss: 0.2365409478545189
# Starting epoch 220/4000.
# Epoch finished ! Loss: 0.23920939713716508
# Starting epoch 221/4000.
# Epoch finished ! Loss: 0.2354157656431198
# Starting epoch 222/4000.
# Epoch finished ! Loss: 0.2383488669991493
# Starting epoch 223/4000.
# Epoch finished ! Loss: 0.23792345225811004
# Starting epoch 224/4000.
# Epoch finished ! Loss: 0.23936983495950698
# Starting epoch 225/4000.
# Epoch finished ! Loss: 0.24373661428689958
# Starting epoch 226/4000.
# Epoch finished ! Loss: 0.23684657514095306
# Starting epoch 227/4000.
# Epoch finished ! Loss: 0.22667508125305175
# Starting epoch 228/4000.
# Epoch finished ! Loss: 0.24548336416482924
# Starting epoch 229/4000.
# Epoch finished ! Loss: 0.2359171986579895
# Starting epoch 230/4000.
# Epoch finished ! Loss: 0.2302737846970558
# Starting epoch 231/4000.
# Epoch finished ! Loss: 0.24501680433750153
# Starting epoch 232/4000.
# Epoch finished ! Loss: 0.24394905269145967
# Starting epoch 233/4000.
# Epoch finished ! Loss: 0.23677164912223816
# Starting epoch 234/4000.
# Epoch finished ! Loss: 0.23423126935958863
# Starting epoch 235/4000.
# Epoch finished ! Loss: 0.22612713277339935
# Starting epoch 236/4000.
# Epoch finished ! Loss: 0.23278880268335342
# Starting epoch 237/4000.
# Epoch finished ! Loss: 0.23740891367197037
# Starting epoch 238/4000.
# Epoch finished ! Loss: 0.232212395966053
# Starting epoch 239/4000.
# Epoch finished ! Loss: 0.2324761688709259
# Starting epoch 240/4000.
# Epoch finished ! Loss: 0.240418042242527
# Starting epoch 241/4000.
# Epoch finished ! Loss: 0.23200035393238067
# Starting epoch 242/4000.
# Epoch finished ! Loss: 0.23378952145576476
# Starting epoch 243/4000.
# Epoch finished ! Loss: 0.238070710003376
# Starting epoch 244/4000.
# Epoch finished ! Loss: 0.23245851844549179
# Starting epoch 245/4000.
# Epoch finished ! Loss: 0.23706526905298234
# Starting epoch 246/4000.
# Epoch finished ! Loss: 0.23934641629457473
# Starting epoch 247/4000.
# Epoch finished ! Loss: 0.24518512338399887
# Starting epoch 248/4000.
# Epoch finished ! Loss: 0.23551846742630006
# Starting epoch 249/4000.
# Epoch finished ! Loss: 0.239611978828907
# Starting epoch 250/4000.
# Epoch finished ! Loss: 0.2382198691368103
# Starting epoch 251/4000.
# Epoch finished ! Loss: 0.2328857496380806
# Starting epoch 252/4000.
# Epoch finished ! Loss: 0.22934969067573546
# Starting epoch 253/4000.
# Epoch finished ! Loss: 0.24930980652570725
# Starting epoch 254/4000.
# Epoch finished ! Loss: 0.24536050707101822
# Starting epoch 255/4000.
# Epoch finished ! Loss: 0.23497429639101028
# Starting epoch 256/4000.
# Epoch finished ! Loss: 0.23290574550628662
# Starting epoch 257/4000.
# Epoch finished ! Loss: 0.23766859620809555
# Starting epoch 258/4000.
# Epoch finished ! Loss: 0.23498857021331787
# Starting epoch 259/4000.
# Epoch finished ! Loss: 0.23813380002975465
# Starting epoch 260/4000.
# Epoch finished ! Loss: 0.23252004534006118
# Starting epoch 261/4000.
# Epoch finished ! Loss: 0.2375602975487709
# Starting epoch 262/4000.
# Epoch finished ! Loss: 0.23059577196836473
# Starting epoch 263/4000.
# Epoch finished ! Loss: 0.2425978571176529
# Starting epoch 264/4000.
# Epoch finished ! Loss: 0.23336775004863738
# Starting epoch 265/4000.
# Epoch finished ! Loss: 0.23361441642045974
# Starting epoch 266/4000.
# Epoch finished ! Loss: 0.2332028105854988
# Starting epoch 267/4000.
# Epoch finished ! Loss: 0.2333563968539238
# Starting epoch 268/4000.
# Epoch finished ! Loss: 0.22841766923666001
# Starting epoch 269/4000.
# Epoch finished ! Loss: 0.2356010288000107
# Starting epoch 270/4000.
# Epoch finished ! Loss: 0.23483987152576447
# Starting epoch 271/4000.
# Epoch finished ! Loss: 0.23411751985549928
# Starting epoch 272/4000.
# Epoch finished ! Loss: 0.2276000812649727
# Starting epoch 273/4000.
# Epoch finished ! Loss: 0.22894050776958466
# Starting epoch 274/4000.
# Epoch finished ! Loss: 0.2376153826713562
# Starting epoch 275/4000.
# Epoch finished ! Loss: 0.22152192145586014
# Starting epoch 276/4000.
# Epoch finished ! Loss: 0.24063907712697982
# Starting epoch 277/4000.
# Epoch finished ! Loss: 0.24543502181768417
# Starting epoch 278/4000.
# Epoch finished ! Loss: 0.23106397986412047
# Starting epoch 279/4000.
# Epoch finished ! Loss: 0.22968747913837434
# Starting epoch 280/4000.
# Epoch finished ! Loss: 0.2298298805952072
# Starting epoch 281/4000.
# Epoch finished ! Loss: 0.23083702921867372
# Starting epoch 282/4000.
# Epoch finished ! Loss: 0.22593316584825515
# Starting epoch 283/4000.
# Epoch finished ! Loss: 0.22467761635780334
# Starting epoch 284/4000.
# Epoch finished ! Loss: 0.22415914684534072
# Starting epoch 285/4000.
# Epoch finished ! Loss: 0.22480399906635284
# Starting epoch 286/4000.
# Epoch finished ! Loss: 0.2287481904029846
# Starting epoch 287/4000.
# Epoch finished ! Loss: 0.23180098235607147
# Starting epoch 288/4000.
# Epoch finished ! Loss: 0.22133367508649826
# Starting epoch 289/4000.
# Epoch finished ! Loss: 0.23495255708694457
# Starting epoch 290/4000.
# Epoch finished ! Loss: 0.2356183111667633
# Starting epoch 291/4000.
# Epoch finished ! Loss: 0.22818491309881211
# Starting epoch 292/4000.
# Epoch finished ! Loss: 0.22816605716943741
# Starting epoch 293/4000.
# Epoch finished ! Loss: 0.22643972039222718
# Starting epoch 294/4000.
# Epoch finished ! Loss: 0.2405075401067734
# Starting epoch 295/4000.
# Epoch finished ! Loss: 0.23326730132102966
# Starting epoch 296/4000.
# Epoch finished ! Loss: 0.2337469756603241
# Starting epoch 297/4000.
# Epoch finished ! Loss: 0.21954791992902756
# Starting epoch 298/4000.
# Epoch finished ! Loss: 0.23127813041210174
# Starting epoch 299/4000.
# Epoch finished ! Loss: 0.2352709636092186
# Starting epoch 300/4000.
# Epoch finished ! Loss: 0.233755025267601
# Starting epoch 301/4000.
# Epoch finished ! Loss: 0.23633556365966796
# Starting epoch 302/4000.
# Epoch finished ! Loss: 0.2233649492263794
# Starting epoch 303/4000.
# Epoch finished ! Loss: 0.2261204406619072
# Starting epoch 304/4000.
# Epoch finished ! Loss: 0.23255692422389984
# Starting epoch 305/4000.
# Epoch finished ! Loss: 0.23492481559515
# Starting epoch 306/4000.
# Epoch finished ! Loss: 0.22533671110868453
# Starting epoch 307/4000.
# Epoch finished ! Loss: 0.22847913950681686
# Starting epoch 308/4000.
# Epoch finished ! Loss: 0.2252033457159996
# Starting epoch 309/4000.
# Epoch finished ! Loss: 0.225971220433712
# Starting epoch 310/4000.
# Epoch finished ! Loss: 0.22497965693473815
# Starting epoch 311/4000.
# Epoch finished ! Loss: 0.22960186898708343
# Starting epoch 312/4000.
# Epoch finished ! Loss: 0.2230603039264679
# Starting epoch 313/4000.
# Epoch finished ! Loss: 0.22357036173343658
# Starting epoch 314/4000.
# Epoch finished ! Loss: 0.2311583012342453
# Starting epoch 315/4000.
# Epoch finished ! Loss: 0.23312009125947952
# Starting epoch 316/4000.
# Epoch finished ! Loss: 0.22766957730054854
# Starting epoch 317/4000.
# Epoch finished ! Loss: 0.22752664536237716
# Starting epoch 318/4000.
# Epoch finished ! Loss: 0.23556933104991912
# Starting epoch 319/4000.
# Epoch finished ! Loss: 0.23314116448163985
# Starting epoch 320/4000.
# Epoch finished ! Loss: 0.22887283861637114
# Starting epoch 321/4000.
# Epoch finished ! Loss: 0.22746712416410447
# Starting epoch 322/4000.
# Epoch finished ! Loss: 0.21578974574804305
# Starting epoch 323/4000.
# Epoch finished ! Loss: 0.23362165093421935
# Starting epoch 324/4000.
# Epoch finished ! Loss: 0.22391001433134078
# Starting epoch 325/4000.
# Epoch finished ! Loss: 0.2239649012684822
# Starting epoch 326/4000.
# Epoch finished ! Loss: 0.23480506092309952
# Starting epoch 327/4000.
# Epoch finished ! Loss: 0.2264211043715477
# Starting epoch 328/4000.
# Epoch finished ! Loss: 0.22804411947727204
# Starting epoch 329/4000.
# Epoch finished ! Loss: 0.23619561046361923
# Starting epoch 330/4000.
# Epoch finished ! Loss: 0.2317185655236244
# Starting epoch 331/4000.
# Epoch finished ! Loss: 0.22308612614870071
# Starting epoch 332/4000.
# Epoch finished ! Loss: 0.23426050394773484
# Starting epoch 333/4000.
# Epoch finished ! Loss: 0.21950852274894714
# Starting epoch 334/4000.
# Epoch finished ! Loss: 0.22604852467775344
# Starting epoch 335/4000.
# Epoch finished ! Loss: 0.23039992451667785
# Starting epoch 336/4000.
# Epoch finished ! Loss: 0.22120224088430404
# Starting epoch 337/4000.
# Epoch finished ! Loss: 0.22663245350122452
# Starting epoch 338/4000.
# Epoch finished ! Loss: 0.22108641415834426
# Starting epoch 339/4000.
# Epoch finished ! Loss: 0.21941915303468704
# Starting epoch 340/4000.
# Epoch finished ! Loss: 0.21632397323846816
# Starting epoch 341/4000.
# Epoch finished ! Loss: 0.22696411609649658
# Starting epoch 342/4000.
# Epoch finished ! Loss: 0.23014771491289138
# Starting epoch 343/4000.
# Epoch finished ! Loss: 0.21977929770946503
# Starting epoch 344/4000.
# Epoch finished ! Loss: 0.22612111121416092
# Starting epoch 345/4000.
# Epoch finished ! Loss: 0.2185188949108124
# Starting epoch 346/4000.
# Epoch finished ! Loss: 0.22485066950321198
# Starting epoch 347/4000.
# Epoch finished ! Loss: 0.23664501011371614
# Starting epoch 348/4000.
# Epoch finished ! Loss: 0.22237788438796996
# Starting epoch 349/4000.
# Epoch finished ! Loss: 0.2269037738442421
# Starting epoch 350/4000.
# Epoch finished ! Loss: 0.22716226279735566
# Starting epoch 351/4000.
# Epoch finished ! Loss: 0.22317147254943848
# Starting epoch 352/4000.
# Epoch finished ! Loss: 0.2319119542837143
# Starting epoch 353/4000.
# Epoch finished ! Loss: 0.22440033555030822
# Starting epoch 354/4000.
# Epoch finished ! Loss: 0.22464876919984816
# Starting epoch 355/4000.
# Epoch finished ! Loss: 0.22286899834871293
# Starting epoch 356/4000.
# Epoch finished ! Loss: 0.22217282354831697
# Starting epoch 357/4000.
# Epoch finished ! Loss: 0.22476591616868974
# Starting epoch 358/4000.
# Epoch finished ! Loss: 0.2412365958094597
# Starting epoch 359/4000.
# Epoch finished ! Loss: 0.22018618434667586
# Starting epoch 360/4000.
# Epoch finished ! Loss: 0.22759511619806289
# Starting epoch 361/4000.
# Epoch finished ! Loss: 0.23036810904741287
# Starting epoch 362/4000.
# Epoch finished ! Loss: 0.21950336694717407
# Starting epoch 363/4000.
# Epoch finished ! Loss: 0.22935280501842498
# Starting epoch 364/4000.
# Epoch finished ! Loss: 0.21619974672794343
# Starting epoch 365/4000.
# Epoch finished ! Loss: 0.21601187139749528
# Starting epoch 366/4000.
# Epoch finished ! Loss: 0.2296440839767456
# Starting epoch 367/4000.
# Epoch finished ! Loss: 0.227725251019001
# Starting epoch 368/4000.
# Epoch finished ! Loss: 0.2242191970348358
# Starting epoch 369/4000.
# Epoch finished ! Loss: 0.2244450718164444
# Starting epoch 370/4000.
# Epoch finished ! Loss: 0.22109983414411544
# Starting epoch 371/4000.
# Epoch finished ! Loss: 0.2246589720249176
# Starting epoch 372/4000.
# Epoch finished ! Loss: 0.21546713560819625
# Starting epoch 373/4000.
# Epoch finished ! Loss: 0.2275662437081337
# Starting epoch 374/4000.
# Epoch finished ! Loss: 0.21905127316713333
# Starting epoch 375/4000.
# Epoch finished ! Loss: 0.21993454396724701
# Starting epoch 376/4000.
# Epoch finished ! Loss: 0.2234477773308754
# Starting epoch 377/4000.
# Epoch finished ! Loss: 0.22175341546535493
# Starting epoch 378/4000.
# Epoch finished ! Loss: 0.21450394839048387
# Starting epoch 379/4000.
# Epoch finished ! Loss: 0.2183404967188835
# Starting epoch 380/4000.
# Epoch finished ! Loss: 0.22129897624254227
# Starting epoch 381/4000.
# Epoch finished ! Loss: 0.22187036871910096
# Starting epoch 382/4000.
# Epoch finished ! Loss: 0.22565321624279022
# Starting epoch 383/4000.
# Epoch finished ! Loss: 0.21684794574975969
# Starting epoch 384/4000.
# Epoch finished ! Loss: 0.22568106800317764
# Starting epoch 385/4000.
# Epoch finished ! Loss: 0.22215010225772858
# Starting epoch 386/4000.
# Epoch finished ! Loss: 0.2228896975517273
# Starting epoch 387/4000.
# Epoch finished ! Loss: 0.2189508080482483
# Starting epoch 388/4000.
# Epoch finished ! Loss: 0.22488550692796708
# Starting epoch 389/4000.
# Epoch finished ! Loss: 0.226949642598629
# Starting epoch 390/4000.
# Epoch finished ! Loss: 0.21855295747518538
# Starting epoch 391/4000.
# Epoch finished ! Loss: 0.22004427015781403
# Starting epoch 392/4000.
# Epoch finished ! Loss: 0.21355350762605668
# Starting epoch 393/4000.
# Epoch finished ! Loss: 0.2239956185221672
# Starting epoch 394/4000.
# Epoch finished ! Loss: 0.2196795403957367
# Starting epoch 395/4000.
# Epoch finished ! Loss: 0.2219537764787674
# Starting epoch 396/4000.
# Epoch finished ! Loss: 0.21896323263645173
# Starting epoch 397/4000.
# Epoch finished ! Loss: 0.22093026340007782
# Starting epoch 398/4000.
# Epoch finished ! Loss: 0.22013530880212784
# Starting epoch 399/4000.
# Epoch finished ! Loss: 0.22090900540351868
# Starting epoch 400/4000.
# Epoch finished ! Loss: 0.21476472169160843
# Starting epoch 401/4000.
# Epoch finished ! Loss: 0.22433988898992538
# Starting epoch 402/4000.
# Epoch finished ! Loss: 0.21973999142646788
# Starting epoch 403/4000.
# Epoch finished ! Loss: 0.21934370845556259
# Starting epoch 404/4000.
# Epoch finished ! Loss: 0.22381676882505416
# Starting epoch 405/4000.
# Epoch finished ! Loss: 0.22142368406057358
# Starting epoch 406/4000.
# Epoch finished ! Loss: 0.21811357289552688
# Starting epoch 407/4000.
# Epoch finished ! Loss: 0.21599425226449967
# Starting epoch 408/4000.
# Epoch finished ! Loss: 0.21654726415872574
# Starting epoch 409/4000.
# Epoch finished ! Loss: 0.22688541263341905
# Starting epoch 410/4000.
# Epoch finished ! Loss: 0.22402272820472718
# Starting epoch 411/4000.
# Epoch finished ! Loss: 0.22490329295396805
# Starting epoch 412/4000.
# Epoch finished ! Loss: 0.22216432094573973
# Starting epoch 413/4000.
# Epoch finished ! Loss: 0.22337643951177596
# Starting epoch 414/4000.
# Epoch finished ! Loss: 0.21486374288797377
# Starting epoch 415/4000.
# Epoch finished ! Loss: 0.21420436948537827
# Starting epoch 416/4000.
# Epoch finished ! Loss: 0.21734148263931274
# Starting epoch 417/4000.
# Epoch finished ! Loss: 0.223786798119545
# Starting epoch 418/4000.
# Epoch finished ! Loss: 0.2247580483555794
# Starting epoch 419/4000.
# Epoch finished ! Loss: 0.22050475031137468
# Starting epoch 420/4000.
# Epoch finished ! Loss: 0.22311056405305862
# Starting epoch 421/4000.
# Epoch finished ! Loss: 0.2242392808198929
# Starting epoch 422/4000.
# Epoch finished ! Loss: 0.21786936670541762
# Starting epoch 423/4000.
# Epoch finished ! Loss: 0.2218511536717415
# Starting epoch 424/4000.
# Epoch finished ! Loss: 0.22841114848852156
# Starting epoch 425/4000.
# Epoch finished ! Loss: 0.22037618160247802
# Starting epoch 426/4000.
# Epoch finished ! Loss: 0.2240445777773857
# Starting epoch 427/4000.
# Epoch finished ! Loss: 0.2271760493516922
# Starting epoch 428/4000.
# Epoch finished ! Loss: 0.21602396070957183
# Starting epoch 429/4000.
# Epoch finished ! Loss: 0.2164706438779831
# Starting epoch 430/4000.
# Epoch finished ! Loss: 0.21103706061840058
# Starting epoch 431/4000.
# Epoch finished ! Loss: 0.2187585487961769
# Starting epoch 432/4000.
# Epoch finished ! Loss: 0.21938737779855727
# Starting epoch 433/4000.
# Epoch finished ! Loss: 0.2182595118880272
# Starting epoch 434/4000.
# Epoch finished ! Loss: 0.21832337081432343
# Starting epoch 435/4000.
# Epoch finished ! Loss: 0.2170329660177231
# Starting epoch 436/4000.
# Epoch finished ! Loss: 0.2253129169344902
# Starting epoch 437/4000.
# Epoch finished ! Loss: 0.21170803606510163
# Starting epoch 438/4000.
# Epoch finished ! Loss: 0.21744519472122192
# Starting epoch 439/4000.
# Epoch finished ! Loss: 0.22296645790338515
# Starting epoch 440/4000.
# Epoch finished ! Loss: 0.21348268538713455
# Starting epoch 441/4000.
# Epoch finished ! Loss: 0.20885275453329086
# Starting epoch 442/4000.
# Epoch finished ! Loss: 0.2249365881085396
# Starting epoch 443/4000.
# Epoch finished ! Loss: 0.22501566410064697
# Starting epoch 444/4000.
# Epoch finished ! Loss: 0.2195485308766365
# Starting epoch 445/4000.
# Epoch finished ! Loss: 0.21600009202957154
# Starting epoch 446/4000.
# Epoch finished ! Loss: 0.2153414383530617
# Starting epoch 447/4000.
# Epoch finished ! Loss: 0.21615267992019654
# Starting epoch 448/4000.
# Epoch finished ! Loss: 0.2129742830991745
# Starting epoch 449/4000.
# Epoch finished ! Loss: 0.21242875158786773
# Starting epoch 450/4000.
# Epoch finished ! Loss: 0.21944106966257096
# Starting epoch 451/4000.
# Epoch finished ! Loss: 0.21773959696292877
# Starting epoch 452/4000.
# Epoch finished ! Loss: 0.21202446073293685
# Starting epoch 453/4000.
# Epoch finished ! Loss: 0.21673339307308198
# Starting epoch 454/4000.
# Epoch finished ! Loss: 0.21905230581760407
# Starting epoch 455/4000.
# Epoch finished ! Loss: 0.2223285511136055
# Starting epoch 456/4000.
# Epoch finished ! Loss: 0.2077987387776375
# Starting epoch 457/4000.
# Epoch finished ! Loss: 0.21182133704423906
# Starting epoch 458/4000.
# Epoch finished ! Loss: 0.21838122755289077
# Starting epoch 459/4000.
# Epoch finished ! Loss: 0.2172355204820633
# Starting epoch 460/4000.
# Epoch finished ! Loss: 0.21255502104759216
# Starting epoch 461/4000.
# Epoch finished ! Loss: 0.2178024873137474
# Starting epoch 462/4000.
# Epoch finished ! Loss: 0.21827161610126494
# Starting epoch 463/4000.
# Epoch finished ! Loss: 0.2203586980700493
# Starting epoch 464/4000.
# Epoch finished ! Loss: 0.21593787223100663
# Starting epoch 465/4000.
# Epoch finished ! Loss: 0.21355319619178773
# Starting epoch 466/4000.
# Epoch finished ! Loss: 0.2097765564918518
# Starting epoch 467/4000.
# Epoch finished ! Loss: 0.21887535601854324
# Starting epoch 468/4000.
# Epoch finished ! Loss: 0.2214699551463127
# Starting epoch 469/4000.
# Epoch finished ! Loss: 0.20769154727458955
# Starting epoch 470/4000.
# Epoch finished ! Loss: 0.22026460021734237
# Starting epoch 471/4000.
# Epoch finished ! Loss: 0.21946678906679154
# Starting epoch 472/4000.
# Epoch finished ! Loss: 0.2257344827055931
# Starting epoch 473/4000.
# Epoch finished ! Loss: 0.2101924389600754
# Starting epoch 474/4000.
# Epoch finished ! Loss: 0.21870012283325196
# Starting epoch 475/4000.
# Epoch finished ! Loss: 0.2241903141140938
# Starting epoch 476/4000.
# Epoch finished ! Loss: 0.20682475864887237
# Starting epoch 477/4000.
# Epoch finished ! Loss: 0.21368275731801986
# Starting epoch 478/4000.
# Epoch finished ! Loss: 0.21561793535947799
# Starting epoch 479/4000.
# Epoch finished ! Loss: 0.21404580026865005
# Starting epoch 480/4000.
# Epoch finished ! Loss: 0.21618467271327974
# Starting epoch 481/4000.
# Epoch finished ! Loss: 0.20891681164503098
# Starting epoch 482/4000.
# Epoch finished ! Loss: 0.20915332138538362
# Starting epoch 483/4000.
# Epoch finished ! Loss: 0.22756588459014893
# Starting epoch 484/4000.
# Epoch finished ! Loss: 0.22114500254392624
# Starting epoch 485/4000.
# Epoch finished ! Loss: 0.2168901965022087
# Starting epoch 486/4000.
# Epoch finished ! Loss: 0.22182144671678544
# Starting epoch 487/4000.
# Epoch finished ! Loss: 0.21903349757194518
# Starting epoch 488/4000.
# Epoch finished ! Loss: 0.22140062600374222
# Starting epoch 489/4000.
# Epoch finished ! Loss: 0.21306944638490677
# Starting epoch 490/4000.
# Epoch finished ! Loss: 0.2155192479491234
# Starting epoch 491/4000.
# Epoch finished ! Loss: 0.2159949868917465
# Starting epoch 492/4000.
# Epoch finished ! Loss: 0.211438949406147
# Starting epoch 493/4000.
# Epoch finished ! Loss: 0.2111328899860382
# Starting epoch 494/4000.
# Epoch finished ! Loss: 0.22059471309185028
# Starting epoch 495/4000.
# Epoch finished ! Loss: 0.21712317764759065
# Starting epoch 496/4000.
# Epoch finished ! Loss: 0.2092873275279999
# Starting epoch 497/4000.
# Epoch finished ! Loss: 0.2097756028175354
# Starting epoch 498/4000.
# Epoch finished ! Loss: 0.21733547002077103
# Starting epoch 499/4000.
# Epoch finished ! Loss: 0.21664490252733232
# Starting epoch 500/4000.
# Epoch finished ! Loss: 0.21755722761154175
# Starting epoch 501/4000.
# Epoch finished ! Loss: 0.21979887038469315
# Starting epoch 502/4000.
# Epoch finished ! Loss: 0.22313294559717178
# Starting epoch 503/4000.
# Epoch finished ! Loss: 0.21003451198339462
# Starting epoch 504/4000.
# Epoch finished ! Loss: 0.2019500583410263
# Starting epoch 505/4000.
# Epoch finished ! Loss: 0.2140850692987442
# Starting epoch 506/4000.
# Epoch finished ! Loss: 0.21251822412014007
# Starting epoch 507/4000.
# Epoch finished ! Loss: 0.21624648123979567
# Starting epoch 508/4000.
# Epoch finished ! Loss: 0.22809385657310485
# Starting epoch 509/4000.
# Epoch finished ! Loss: 0.21815214902162552
# Starting epoch 510/4000.
# Epoch finished ! Loss: 0.21272834986448289
# Starting epoch 511/4000.
# Epoch finished ! Loss: 0.21931028217077256
# Starting epoch 512/4000.
# Epoch finished ! Loss: 0.22430658638477324
# Starting epoch 513/4000.
# Epoch finished ! Loss: 0.22135127782821656
# Starting epoch 514/4000.
# Epoch finished ! Loss: 0.21129020154476166
# Starting epoch 515/4000.
# Epoch finished ! Loss: 0.21716308146715163
# Starting epoch 516/4000.
# Epoch finished ! Loss: 0.21850312501192093
# Starting epoch 517/4000.
# Epoch finished ! Loss: 0.2218225210905075
# Starting epoch 518/4000.
# Epoch finished ! Loss: 0.2209211051464081
# Starting epoch 519/4000.
# Epoch finished ! Loss: 0.20890207290649415
# Starting epoch 520/4000.
# Epoch finished ! Loss: 0.2200246497988701
# Starting epoch 521/4000.
# Epoch finished ! Loss: 0.21598609834909438
# Starting epoch 522/4000.
# Epoch finished ! Loss: 0.21311322301626207
# Starting epoch 523/4000.
# Epoch finished ! Loss: 0.21930461525917053
# Starting epoch 524/4000.
# Epoch finished ! Loss: 0.22167286574840545
# Starting epoch 525/4000.
# Epoch finished ! Loss: 0.22082646042108536
# Starting epoch 526/4000.
# Epoch finished ! Loss: 0.21490090042352678
# Starting epoch 527/4000.
# Epoch finished ! Loss: 0.21859968602657318
# Starting epoch 528/4000.
# Epoch finished ! Loss: 0.21183601021766663
# Starting epoch 529/4000.
# Epoch finished ! Loss: 0.2082340806722641
# Starting epoch 530/4000.
# Epoch finished ! Loss: 0.2172828197479248
# Starting epoch 531/4000.
# Epoch finished ! Loss: 0.21822662949562072
# Starting epoch 532/4000.
# Epoch finished ! Loss: 0.2175041601061821
# Starting epoch 533/4000.
# Epoch finished ! Loss: 0.21257171630859376
# Starting epoch 534/4000.
# Epoch finished ! Loss: 0.21556119620800018
# Starting epoch 535/4000.
# Epoch finished ! Loss: 0.22325850576162337
# Starting epoch 536/4000.
# Epoch finished ! Loss: 0.21358802318572997
# Starting epoch 537/4000.
# Epoch finished ! Loss: 0.2144994005560875
# Starting epoch 538/4000.
# Epoch finished ! Loss: 0.21217939853668213
# Starting epoch 539/4000.
# Epoch finished ! Loss: 0.21834704279899597
# Starting epoch 540/4000.
# Epoch finished ! Loss: 0.20730348378419877
# Starting epoch 541/4000.
# Epoch finished ! Loss: 0.2210019811987877
# Starting epoch 542/4000.
# Epoch finished ! Loss: 0.2054486930370331
# Starting epoch 543/4000.
# Epoch finished ! Loss: 0.21074921637773514
# Starting epoch 544/4000.
# Epoch finished ! Loss: 0.21209982335567473
# Starting epoch 545/4000.
# Epoch finished ! Loss: 0.2098457023501396
# Starting epoch 546/4000.
# Epoch finished ! Loss: 0.2148065134882927
# Starting epoch 547/4000.
# Epoch finished ! Loss: 0.21521401405334473
# Starting epoch 548/4000.
# Epoch finished ! Loss: 0.20970491617918013
# Starting epoch 549/4000.
# Epoch finished ! Loss: 0.21623356640338898
# Starting epoch 550/4000.
# Epoch finished ! Loss: 0.20951129049062728
# Starting epoch 551/4000.
# Epoch finished ! Loss: 0.20938325077295303
# Starting epoch 552/4000.
# Epoch finished ! Loss: 0.20542774498462676
# Starting epoch 553/4000.
# Epoch finished ! Loss: 0.21440806984901428
# Starting epoch 554/4000.
# Epoch finished ! Loss: 0.2073373541235924
# Starting epoch 555/4000.
# Epoch finished ! Loss: 0.20973942577838897
# Starting epoch 556/4000.
# Epoch finished ! Loss: 0.21821884959936141
# Starting epoch 557/4000.
# Epoch finished ! Loss: 0.21243864595890044
# Starting epoch 558/4000.
# Epoch finished ! Loss: 0.20575589090585708
# Starting epoch 559/4000.
# Epoch finished ! Loss: 0.21254006177186965
# Starting epoch 560/4000.
# Epoch finished ! Loss: 0.21815121918916702
# Starting epoch 561/4000.
# Epoch finished ! Loss: 0.20938166081905366
# Starting epoch 562/4000.
# Epoch finished ! Loss: 0.21912061423063278
# Starting epoch 563/4000.
# Epoch finished ! Loss: 0.22266327887773513
# Starting epoch 564/4000.
# Epoch finished ! Loss: 0.21179050654172898
# Starting epoch 565/4000.
# Epoch finished ! Loss: 0.21770361363887786
# Starting epoch 566/4000.
# Epoch finished ! Loss: 0.21724448800086976
# Starting epoch 567/4000.
# Epoch finished ! Loss: 0.2094651460647583
# Starting epoch 568/4000.
# Epoch finished ! Loss: 0.22090450376272203
# Starting epoch 569/4000.
# Epoch finished ! Loss: 0.21963928788900375
# Starting epoch 570/4000.
# Epoch finished ! Loss: 0.21271904706954955
# Starting epoch 571/4000.
# Epoch finished ! Loss: 0.21138288527727128
# Starting epoch 572/4000.
# Epoch finished ! Loss: 0.22619205415248872
# Starting epoch 573/4000.
# Epoch finished ! Loss: 0.2079869791865349
# Starting epoch 574/4000.
# Epoch finished ! Loss: 0.2194089412689209
# Starting epoch 575/4000.
# Epoch finished ! Loss: 0.2171584412455559
# Starting epoch 576/4000.
# Epoch finished ! Loss: 0.2202589899301529
# Starting epoch 577/4000.
# Epoch finished ! Loss: 0.21125043779611588
# Starting epoch 578/4000.
# Epoch finished ! Loss: 0.21933604031801224
# Starting epoch 579/4000.
# Epoch finished ! Loss: 0.2092314749956131
# Starting epoch 580/4000.
# Epoch finished ! Loss: 0.2122553586959839
# Starting epoch 581/4000.
# Epoch finished ! Loss: 0.21040432006120682
# Starting epoch 582/4000.
# Epoch finished ! Loss: 0.21508121937513353
# Starting epoch 583/4000.
# Epoch finished ! Loss: 0.20600093603134156
# Starting epoch 584/4000.
# Epoch finished ! Loss: 0.20803216397762297
# Starting epoch 585/4000.
# Epoch finished ! Loss: 0.21604350358247756
# Starting epoch 586/4000.
# Epoch finished ! Loss: 0.2117200031876564
# Starting epoch 587/4000.
# Epoch finished ! Loss: 0.20833175033330917
# Starting epoch 588/4000.
# Epoch finished ! Loss: 0.21781523078680037
# Starting epoch 589/4000.
# Epoch finished ! Loss: 0.21619459837675095
# Starting epoch 590/4000.
# Epoch finished ! Loss: 0.20929157584905625
# Starting epoch 591/4000.
# Epoch finished ! Loss: 0.20988887846469878
# Starting epoch 592/4000.
# Epoch finished ! Loss: 0.2049091026186943
# Starting epoch 593/4000.
# Epoch finished ! Loss: 0.2065456986427307
# Starting epoch 594/4000.
# Epoch finished ! Loss: 0.2025586947798729
# Starting epoch 595/4000.
# Epoch finished ! Loss: 0.20320896357297896
# Starting epoch 596/4000.
# Epoch finished ! Loss: 0.20789366066455842
# Starting epoch 597/4000.
# Epoch finished ! Loss: 0.21104957014322281
# Starting epoch 598/4000.
# Epoch finished ! Loss: 0.21670814454555512
# Starting epoch 599/4000.
# Epoch finished ! Loss: 0.20734757035970688
# Starting epoch 600/4000.
# Epoch finished ! Loss: 0.21359479576349258
# Starting epoch 601/4000.
# Epoch finished ! Loss: 0.20599309206008912
# Starting epoch 602/4000.
# Epoch finished ! Loss: 0.21069800853729248
# Starting epoch 603/4000.
# Epoch finished ! Loss: 0.22246966361999512
# Starting epoch 604/4000.
# Epoch finished ! Loss: 0.21229417771100997
# Starting epoch 605/4000.
# Epoch finished ! Loss: 0.2148531675338745
# Starting epoch 606/4000.
# Epoch finished ! Loss: 0.20829245448112488
# Starting epoch 607/4000.
# Epoch finished ! Loss: 0.21802029013633728
# Starting epoch 608/4000.
# Epoch finished ! Loss: 0.22779844850301742
# Starting epoch 609/4000.
# Epoch finished ! Loss: 0.20719005763530732
# Starting epoch 610/4000.
# Epoch finished ! Loss: 0.20822578221559523
# Starting epoch 611/4000.
# Epoch finished ! Loss: 0.21772413998842238
# Starting epoch 612/4000.
# Epoch finished ! Loss: 0.2138327181339264
# Starting epoch 613/4000.
# Epoch finished ! Loss: 0.21398090571165085
# Starting epoch 614/4000.
# Epoch finished ! Loss: 0.20770560801029206
# Starting epoch 615/4000.
# Epoch finished ! Loss: 0.21497985273599624
# Starting epoch 616/4000.
# Epoch finished ! Loss: 0.21260295957326888
# Starting epoch 617/4000.
# Epoch finished ! Loss: 0.2136277213692665
# Starting epoch 618/4000.
# Epoch finished ! Loss: 0.2111247092485428
# Starting epoch 619/4000.
# Epoch finished ! Loss: 0.2101668521761894
# Starting epoch 620/4000.
# Epoch finished ! Loss: 0.20814866721630096
# Starting epoch 621/4000.
# Epoch finished ! Loss: 0.2097553864121437
# Starting epoch 622/4000.
# Epoch finished ! Loss: 0.19972966909408568
# Starting epoch 623/4000.
# Epoch finished ! Loss: 0.21846118122339248
# Starting epoch 624/4000.
# Epoch finished ! Loss: 0.21636753380298615
# Starting epoch 625/4000.
# Epoch finished ! Loss: 0.21251117140054704
# Starting epoch 626/4000.
# Epoch finished ! Loss: 0.21290062069892884
# Starting epoch 627/4000.
# Epoch finished ! Loss: 0.2020994395017624
# Starting epoch 628/4000.
# Epoch finished ! Loss: 0.21504803746938705
# Starting epoch 629/4000.
# Epoch finished ! Loss: 0.21160323917865753
# Starting epoch 630/4000.
# Epoch finished ! Loss: 0.21618010550737382
# Starting epoch 631/4000.
# Epoch finished ! Loss: 0.21335578560829163
# Starting epoch 632/4000.
# Epoch finished ! Loss: 0.2064467340707779
# Starting epoch 633/4000.
# Epoch finished ! Loss: 0.20457151234149934
# Starting epoch 634/4000.
# Epoch finished ! Loss: 0.2094656988978386
# Starting epoch 635/4000.
# Epoch finished ! Loss: 0.21346878558397292
# Starting epoch 636/4000.
# Epoch finished ! Loss: 0.21370764076709747
# Starting epoch 637/4000.
# Epoch finished ! Loss: 0.21958991438150405
# Starting epoch 638/4000.
# Epoch finished ! Loss: 0.2106340616941452
# Starting epoch 639/4000.
# Epoch finished ! Loss: 0.21666911393404006
# Starting epoch 640/4000.
# Epoch finished ! Loss: 0.2094644144177437
# Starting epoch 641/4000.
# Epoch finished ! Loss: 0.20679989010095595
# Starting epoch 642/4000.
# Epoch finished ! Loss: 0.2096385806798935
# Starting epoch 643/4000.
# Epoch finished ! Loss: 0.2098092883825302
# Starting epoch 644/4000.
# Epoch finished ! Loss: 0.21586055308580399
# Starting epoch 645/4000.
# Epoch finished ! Loss: 0.20594342052936554
# Starting epoch 646/4000.
# Epoch finished ! Loss: 0.21207911968231202
# Starting epoch 647/4000.
# Epoch finished ! Loss: 0.20634166300296783
# Starting epoch 648/4000.
# Epoch finished ! Loss: 0.2081749588251114
# Starting epoch 649/4000.
# Epoch finished ! Loss: 0.21526235193014145
# Starting epoch 650/4000.
# Epoch finished ! Loss: 0.21385327577590943
# Starting epoch 651/4000.
# Epoch finished ! Loss: 0.21829479336738586
# Starting epoch 652/4000.
# Epoch finished ! Loss: 0.2022402763366699
# Starting epoch 653/4000.
# Epoch finished ! Loss: 0.20497815012931825
# Starting epoch 654/4000.
# Epoch finished ! Loss: 0.20994891077280045
# Starting epoch 655/4000.
# Epoch finished ! Loss: 0.20229087620973588
# Starting epoch 656/4000.
# Epoch finished ! Loss: 0.2075878158211708
# Starting epoch 657/4000.
# Epoch finished ! Loss: 0.20777243971824647
# Starting epoch 658/4000.
# Epoch finished ! Loss: 0.2105164721608162
# Starting epoch 659/4000.
# Epoch finished ! Loss: 0.20684417337179184
# Starting epoch 660/4000.
# Epoch finished ! Loss: 0.20594109147787093
# Starting epoch 661/4000.
# Epoch finished ! Loss: 0.2094614624977112
# Starting epoch 662/4000.
# Epoch finished ! Loss: 0.21021365523338317
# Starting epoch 663/4000.
# Epoch finished ! Loss: 0.2114219531416893
# Starting epoch 664/4000.
# Epoch finished ! Loss: 0.21040729731321334
# Starting epoch 665/4000.
# Epoch finished ! Loss: 0.2109267607331276
# Starting epoch 666/4000.
# Epoch finished ! Loss: 0.21308396607637406
# Starting epoch 667/4000.
# Epoch finished ! Loss: 0.21799230128526687
# Starting epoch 668/4000.
# Epoch finished ! Loss: 0.20593771189451218
# Starting epoch 669/4000.
# Epoch finished ! Loss: 0.20957963764667512
# Starting epoch 670/4000.
# Epoch finished ! Loss: 0.20829105377197266
# Starting epoch 671/4000.
# Epoch finished ! Loss: 0.21373751759529114
# Starting epoch 672/4000.
# Epoch finished ! Loss: 0.21222581565380097
# Starting epoch 673/4000.
# Epoch finished ! Loss: 0.19910168200731276
# Starting epoch 674/4000.
# Epoch finished ! Loss: 0.2088012143969536
# Starting epoch 675/4000.
# Epoch finished ! Loss: 0.21208928227424623
# Starting epoch 676/4000.
# Epoch finished ! Loss: 0.2099853977560997
# Starting epoch 677/4000.
# Epoch finished ! Loss: 0.19889280647039415
# Starting epoch 678/4000.
# Epoch finished ! Loss: 0.20723012536764146
# Starting epoch 679/4000.
# Epoch finished ! Loss: 0.20826567113399505
# Starting epoch 680/4000.
# Epoch finished ! Loss: 0.21141330152750015
# Starting epoch 681/4000.
# Epoch finished ! Loss: 0.20254024118185043
# Starting epoch 682/4000.
# Epoch finished ! Loss: 0.21218699365854263
# Starting epoch 683/4000.
# Epoch finished ! Loss: 0.20625820904970169
# Starting epoch 684/4000.
# Epoch finished ! Loss: 0.20918481349945067
# Starting epoch 685/4000.
# Epoch finished ! Loss: 0.21047201454639436
# Starting epoch 686/4000.
# Epoch finished ! Loss: 0.22029053717851638
# Starting epoch 687/4000.
# Epoch finished ! Loss: 0.2180756986141205
# Starting epoch 688/4000.
# Epoch finished ! Loss: 0.21066353917121888
# Starting epoch 689/4000.
# Epoch finished ! Loss: 0.20949871242046356
# Starting epoch 690/4000.
# Epoch finished ! Loss: 0.21665649712085724
# Starting epoch 691/4000.
# Epoch finished ! Loss: 0.2146158441901207
# Starting epoch 692/4000.
# Epoch finished ! Loss: 0.21123423278331757
# Starting epoch 693/4000.
# Epoch finished ! Loss: 0.20384206920862197
# Starting epoch 694/4000.
# Epoch finished ! Loss: 0.20849044770002365
# Starting epoch 695/4000.
# Epoch finished ! Loss: 0.20625020414590836
# Starting epoch 696/4000.
# Epoch finished ! Loss: 0.20785938054323197
# Starting epoch 697/4000.
# Epoch finished ! Loss: 0.2108371376991272
# Starting epoch 698/4000.
# Epoch finished ! Loss: 0.2009750038385391
# Starting epoch 699/4000.
# Epoch finished ! Loss: 0.20833988040685653
# Starting epoch 700/4000.
# Epoch finished ! Loss: 0.20163300782442092
# Starting epoch 701/4000.
# Epoch finished ! Loss: 0.2070177897810936
# Starting epoch 702/4000.
# Epoch finished ! Loss: 0.21214038133621216
# Starting epoch 703/4000.
# ...
# Epoch finished ! Loss: 0.1727046400308609
# Starting epoch 2478/4000.
# Epoch finished ! Loss: 0.17179488986730576
# Starting epoch 2479/4000.
# Epoch finished ! Loss: 0.17881591767072677
# Starting epoch 2480/4000.
# Epoch finished ! Loss: 0.172541643679142
# Starting epoch 2481/4000.
# Epoch finished ! Loss: 0.16969362050294876
# Starting epoch 2482/4000.
# Epoch finished ! Loss: 0.17581194639205933
# Starting epoch 2483/4000.
# Epoch finished ! Loss: 0.17044249773025513
# Starting epoch 2484/4000.
# Epoch finished ! Loss: 0.17432470470666886
# Starting epoch 2485/4000.
# Epoch finished ! Loss: 0.17698565125465393
# Starting epoch 2486/4000.
# Epoch finished ! Loss: 0.17366334199905395
# Starting epoch 2487/4000.
# Epoch finished ! Loss: 0.17224448770284653
# Starting epoch 2488/4000.
# Epoch finished ! Loss: 0.17674339711666107
# Starting epoch 2489/4000.
# Epoch finished ! Loss: 0.17765897661447524
# Starting epoch 2490/4000.
# Epoch finished ! Loss: 0.17248537689447402
# Starting epoch 2491/4000.
# Epoch finished ! Loss: 0.17356860190629958
# Starting epoch 2492/4000.
# Epoch finished ! Loss: 0.1723427727818489
# Starting epoch 2493/4000.
# Epoch finished ! Loss: 0.17250004410743713
# Starting epoch 2494/4000.
# Epoch finished ! Loss: 0.16891209930181503
# Starting epoch 2495/4000.
# Epoch finished ! Loss: 0.1696147695183754
# Starting epoch 2496/4000.
# Epoch finished ! Loss: 0.17550405859947205
# Starting epoch 2497/4000.
# Epoch finished ! Loss: 0.172392076253891
# Starting epoch 2498/4000.
# Epoch finished ! Loss: 0.17371196746826173
# Starting epoch 2499/4000.
# Epoch finished ! Loss: 0.17757685780525206
# Starting epoch 2500/4000.
# Epoch finished ! Loss: 0.17183571606874465
# Starting epoch 2501/4000.
# Epoch finished ! Loss: 0.1719413548707962
# Starting epoch 2502/4000.
# Epoch finished ! Loss: 0.1757437601685524
# Starting epoch 2503/4000.
# Epoch finished ! Loss: 0.16896265745162964
# Starting epoch 2504/4000.
# Epoch finished ! Loss: 0.17362199425697328
# Starting epoch 2505/4000.
# Epoch finished ! Loss: 0.17260516732931136
# Starting epoch 2506/4000.
# Epoch finished ! Loss: 0.17244701832532883
# Starting epoch 2507/4000.
# Epoch finished ! Loss: 0.1688460424542427
# Starting epoch 2508/4000.
# Epoch finished ! Loss: 0.17510731369256974
# Starting epoch 2509/4000.
# Epoch finished ! Loss: 0.1735556960105896
# Starting epoch 2510/4000.
# Epoch finished ! Loss: 0.16984920650720597
# Starting epoch 2511/4000.
# Epoch finished ! Loss: 0.18065598011016845
# Starting epoch 2512/4000.
# Epoch finished ! Loss: 0.16728790253400802
# Starting epoch 2513/4000.
# Epoch finished ! Loss: 0.17526938170194625
# Starting epoch 2514/4000.
# Epoch finished ! Loss: 0.17926608622074128
# Starting epoch 2515/4000.
# Epoch finished ! Loss: 0.17401252835988998
# Starting epoch 2516/4000.
# Epoch finished ! Loss: 0.17378735393285752
# Starting epoch 2517/4000.
# Epoch finished ! Loss: 0.1748113751411438
# Starting epoch 2518/4000.
# Epoch finished ! Loss: 0.1687392845749855
# Starting epoch 2519/4000.
# Epoch finished ! Loss: 0.1697766050696373
# Starting epoch 2520/4000.
# Epoch finished ! Loss: 0.1736333042383194
# Starting epoch 2521/4000.
# Epoch finished ! Loss: 0.17804455608129502
# Starting epoch 2522/4000.
# Epoch finished ! Loss: 0.17444346845149994
# Starting epoch 2523/4000.
# Epoch finished ! Loss: 0.17571838051080704
# Starting epoch 2524/4000.
# Epoch finished ! Loss: 0.17624395042657853
# Starting epoch 2525/4000.
# Epoch finished ! Loss: 0.17731342166662217
# Starting epoch 2526/4000.
# Epoch finished ! Loss: 0.16821925193071366
# Starting epoch 2527/4000.
# Epoch finished ! Loss: 0.16572228521108628
# Starting epoch 2528/4000.
# Epoch finished ! Loss: 0.17836265116930008
# Starting epoch 2529/4000.
# Epoch finished ! Loss: 0.17539610117673873
# Starting epoch 2530/4000.
# Epoch finished ! Loss: 0.1745949000120163
# Starting epoch 2531/4000.
# Epoch finished ! Loss: 0.17540936768054963
# Starting epoch 2532/4000.
# Epoch finished ! Loss: 0.17319903671741485
# Starting epoch 2533/4000.
# Epoch finished ! Loss: 0.17145004719495774
# Starting epoch 2534/4000.
# Epoch finished ! Loss: 0.1711781442165375
# Starting epoch 2535/4000.
# Epoch finished ! Loss: 0.17329581081867218
# Starting epoch 2536/4000.
# Epoch finished ! Loss: 0.1753830075263977
# Starting epoch 2537/4000.
# Epoch finished ! Loss: 0.1742592990398407
# Starting epoch 2538/4000.
# Epoch finished ! Loss: 0.17336484789848328
# Starting epoch 2539/4000.
# Epoch finished ! Loss: 0.1739479809999466
# Starting epoch 2540/4000.
# Epoch finished ! Loss: 0.17647797763347625
# Starting epoch 2541/4000.
# Epoch finished ! Loss: 0.17306195944547653
# Starting epoch 2542/4000.
# Epoch finished ! Loss: 0.18148289620876312
# Starting epoch 2543/4000.
# Epoch finished ! Loss: 0.17102064192295074
# Starting epoch 2544/4000.
# Epoch finished ! Loss: 0.17571442276239396
# Starting epoch 2545/4000.
# Epoch finished ! Loss: 0.17708104997873306
# Starting epoch 2546/4000.
# Epoch finished ! Loss: 0.17783386558294295
# Starting epoch 2547/4000.
# Epoch finished ! Loss: 0.1692910373210907
# Starting epoch 2548/4000.
# Epoch finished ! Loss: 0.17160663902759551
# Starting epoch 2549/4000.
# Epoch finished ! Loss: 0.1710606798529625
# Starting epoch 2550/4000.
# Epoch finished ! Loss: 0.1743798464536667
# Starting epoch 2551/4000.
# Epoch finished ! Loss: 0.171823588013649
# Starting epoch 2552/4000.
# Epoch finished ! Loss: 0.17085040956735612
# Starting epoch 2553/4000.
# Epoch finished ! Loss: 0.18082880675792695
# Starting epoch 2554/4000.
# Epoch finished ! Loss: 0.1707897111773491
# Starting epoch 2555/4000.
# Epoch finished ! Loss: 0.17805525809526443
# Starting epoch 2556/4000.
# Epoch finished ! Loss: 0.1747354581952095
# Starting epoch 2557/4000.
# Epoch finished ! Loss: 0.17631529569625853
# Starting epoch 2558/4000.
# Epoch finished ! Loss: 0.17502087950706482
# Starting epoch 2559/4000.
# Epoch finished ! Loss: 0.17306868880987167
# Starting epoch 2560/4000.
# Epoch finished ! Loss: 0.17768013924360276
# Starting epoch 2561/4000.
# Epoch finished ! Loss: 0.1699945241212845
# Starting epoch 2562/4000.
# Epoch finished ! Loss: 0.16732650995254517
# Starting epoch 2563/4000.
# Epoch finished ! Loss: 0.1679336592555046
# Starting epoch 2564/4000.
# Epoch finished ! Loss: 0.1776156023144722
# Starting epoch 2565/4000.
# Epoch finished ! Loss: 0.17120563685894014
# Starting epoch 2566/4000.
# Epoch finished ! Loss: 0.17270425111055374
# Starting epoch 2567/4000.
# Epoch finished ! Loss: 0.17644286900758743
# Starting epoch 2568/4000.
# Epoch finished ! Loss: 0.17373660951852798
# Starting epoch 2569/4000.
# Epoch finished ! Loss: 0.17473403066396714
# Starting epoch 2570/4000.
# Epoch finished ! Loss: 0.17080262899398804
# Starting epoch 2571/4000.
# Epoch finished ! Loss: 0.17637294679880142
# Starting epoch 2572/4000.
# Epoch finished ! Loss: 0.17318440079689026
# Starting epoch 2573/4000.
# Epoch finished ! Loss: 0.18123735785484313
# Starting epoch 2574/4000.
# Epoch finished ! Loss: 0.171809558570385
# Starting epoch 2575/4000.
# Epoch finished ! Loss: 0.17212174981832504
# Starting epoch 2576/4000.
# Epoch finished ! Loss: 0.17411257922649384
# Starting epoch 2577/4000.
# Epoch finished ! Loss: 0.16536043286323548
# Starting epoch 2578/4000.
# Epoch finished ! Loss: 0.1663164258003235
# Starting epoch 2579/4000.
# Epoch finished ! Loss: 0.17540693879127503
# Starting epoch 2580/4000.
# Epoch finished ! Loss: 0.17340200394392014
# Starting epoch 2581/4000.
# Epoch finished ! Loss: 0.1804538518190384
# Starting epoch 2582/4000.
# Epoch finished ! Loss: 0.16878235340118408
# Starting epoch 2583/4000.
# Epoch finished ! Loss: 0.1712767079472542
# Starting epoch 2584/4000.
# Epoch finished ! Loss: 0.17573186308145522
# Starting epoch 2585/4000.
# Epoch finished ! Loss: 0.1671296015381813
# Starting epoch 2586/4000.
# Epoch finished ! Loss: 0.17586858123540877
# Starting epoch 2587/4000.
# Epoch finished ! Loss: 0.1739207997918129
# Starting epoch 2588/4000.
# Epoch finished ! Loss: 0.17640413641929625
# Starting epoch 2589/4000.
# Epoch finished ! Loss: 0.17436471432447434
# Starting epoch 2590/4000.
# Epoch finished ! Loss: 0.1734638512134552
# Starting epoch 2591/4000.
# Epoch finished ! Loss: 0.17103392630815506
# Starting epoch 2592/4000.
# Epoch finished ! Loss: 0.16825534403324127
# Starting epoch 2593/4000.
# Epoch finished ! Loss: 0.17358710914850234
# Starting epoch 2594/4000.
# Epoch finished ! Loss: 0.1742003858089447
# Starting epoch 2595/4000.
# Epoch finished ! Loss: 0.17396861612796782
# Starting epoch 2596/4000.
# Epoch finished ! Loss: 0.16993642300367356
# Starting epoch 2597/4000.
# Epoch finished ! Loss: 0.16570926904678346
# Starting epoch 2598/4000.
# Epoch finished ! Loss: 0.17522843033075333
# Starting epoch 2599/4000.
# Epoch finished ! Loss: 0.1680891901254654
# Starting epoch 2600/4000.
# Epoch finished ! Loss: 0.1737544298171997
# Starting epoch 2601/4000.
# Epoch finished ! Loss: 0.1742401584982872
# Starting epoch 2602/4000.
# Epoch finished ! Loss: 0.17204616069793702
# Starting epoch 2603/4000.
# Epoch finished ! Loss: 0.1758795738220215
# Starting epoch 2604/4000.
# Epoch finished ! Loss: 0.17205215245485306
# Starting epoch 2605/4000.
# Epoch finished ! Loss: 0.16972977072000503
# Starting epoch 2606/4000.
# Epoch finished ! Loss: 0.17336653620004655
# Starting epoch 2607/4000.
# Epoch finished ! Loss: 0.17115655690431594
# Starting epoch 2608/4000.
# Epoch finished ! Loss: 0.17959076911211014
# Starting epoch 2609/4000.
# Epoch finished ! Loss: 0.17119744867086412
# Starting epoch 2610/4000.
# Epoch finished ! Loss: 0.1710707113146782
# Starting epoch 2611/4000.
# Epoch finished ! Loss: 0.17261173576116562
# Starting epoch 2612/4000.
# Epoch finished ! Loss: 0.17675460278987884
# Starting epoch 2613/4000.
# Epoch finished ! Loss: 0.17451515346765517
# Starting epoch 2614/4000.
# Epoch finished ! Loss: 0.1767221823334694
# Starting epoch 2615/4000.
# Epoch finished ! Loss: 0.1704955980181694
# Starting epoch 2616/4000.
# Epoch finished ! Loss: 0.17675715684890747
# Starting epoch 2617/4000.
# Epoch finished ! Loss: 0.1798758715391159
# Starting epoch 2618/4000.
# Epoch finished ! Loss: 0.17506814897060394
# Starting epoch 2619/4000.
# Epoch finished ! Loss: 0.16937980353832244
# Starting epoch 2620/4000.
# Epoch finished ! Loss: 0.17098818868398666
# Starting epoch 2621/4000.
# Epoch finished ! Loss: 0.17375686317682265
# Starting epoch 2622/4000.
# Epoch finished ! Loss: 0.17498528212308884
# Starting epoch 2623/4000.
# Epoch finished ! Loss: 0.17831121236085892
# Starting epoch 2624/4000.
# Epoch finished ! Loss: 0.1743251219391823
# Starting epoch 2625/4000.
# Epoch finished ! Loss: 0.16682856678962707
# Starting epoch 2626/4000.
# Epoch finished ! Loss: 0.17555604875087738
# Starting epoch 2627/4000.
# Epoch finished ! Loss: 0.17737092226743698
# Starting epoch 2628/4000.
# Epoch finished ! Loss: 0.17224177569150925
# Starting epoch 2629/4000.
# Epoch finished ! Loss: 0.17388359010219573
# Starting epoch 2630/4000.
# Epoch finished ! Loss: 0.1773112565279007
# Starting epoch 2631/4000.
# Epoch finished ! Loss: 0.1751851975917816
# Starting epoch 2632/4000.
# Epoch finished ! Loss: 0.17484520077705384
# Starting epoch 2633/4000.
# Epoch finished ! Loss: 0.1712157517671585
# Starting epoch 2634/4000.
# Epoch finished ! Loss: 0.17058925181627274
# Starting epoch 2635/4000.
# Epoch finished ! Loss: 0.16970552057027816
# Starting epoch 2636/4000.
# Epoch finished ! Loss: 0.17388778775930405
# Starting epoch 2637/4000.
# Epoch finished ! Loss: 0.17240174114704132
# Starting epoch 2638/4000.
# Epoch finished ! Loss: 0.17694337368011476
# Starting epoch 2639/4000.
# Epoch finished ! Loss: 0.17220213562250136
# Starting epoch 2640/4000.
# Epoch finished ! Loss: 0.17037208527326583
# Starting epoch 2641/4000.
# Epoch finished ! Loss: 0.17332399636507034
# Starting epoch 2642/4000.
# Epoch finished ! Loss: 0.1771725296974182
# Starting epoch 2643/4000.
# Epoch finished ! Loss: 0.1741536170244217
# Starting epoch 2644/4000.
# Epoch finished ! Loss: 0.17459920197725295
# Starting epoch 2645/4000.
# Epoch finished ! Loss: 0.17500608712434768
# Starting epoch 2646/4000.
# Epoch finished ! Loss: 0.18158579468727112
# Starting epoch 2647/4000.
# Epoch finished ! Loss: 0.17267506420612336
# Starting epoch 2648/4000.
# Epoch finished ! Loss: 0.1708409532904625
# Starting epoch 2649/4000.
# Epoch finished ! Loss: 0.1751965969800949
# Starting epoch 2650/4000.
# Epoch finished ! Loss: 0.17296697348356246
# Starting epoch 2651/4000.
# Epoch finished ! Loss: 0.17968542575836183
# Starting epoch 2652/4000.
# Epoch finished ! Loss: 0.17698831260204315
# Starting epoch 2653/4000.
# Epoch finished ! Loss: 0.16678424328565597
# Starting epoch 2654/4000.
# Epoch finished ! Loss: 0.17279373556375505
# Starting epoch 2655/4000.
# Epoch finished ! Loss: 0.16918043345212935
# Starting epoch 2656/4000.
# Epoch finished ! Loss: 0.1753266215324402
# Starting epoch 2657/4000.
# Epoch finished ! Loss: 0.1704387202858925
# Starting epoch 2658/4000.
# Epoch finished ! Loss: 0.1729739561676979
# Starting epoch 2659/4000.
# Epoch finished ! Loss: 0.1681669145822525
# Starting epoch 2660/4000.
# Epoch finished ! Loss: 0.16987788528203965
# Starting epoch 2661/4000.
# Epoch finished ! Loss: 0.16921505481004714
# Starting epoch 2662/4000.
# Epoch finished ! Loss: 0.1737332373857498
# Starting epoch 2663/4000.
# Epoch finished ! Loss: 0.179964779317379
# Starting epoch 2664/4000.
# Epoch finished ! Loss: 0.17468404471874238
# Starting epoch 2665/4000.
# Epoch finished ! Loss: 0.17208441495895385
# Starting epoch 2666/4000.
# Epoch finished ! Loss: 0.17543412894010543
# Starting epoch 2667/4000.
# Epoch finished ! Loss: 0.17496222704648973
# Starting epoch 2668/4000.
# Epoch finished ! Loss: 0.17637979388237
# Starting epoch 2669/4000.
# Epoch finished ! Loss: 0.17460937052965164
# Starting epoch 2670/4000.
# Epoch finished ! Loss: 0.1740424230694771
# Starting epoch 2671/4000.
# Epoch finished ! Loss: 0.1663529634475708
# Starting epoch 2672/4000.
# Epoch finished ! Loss: 0.17151722609996795
# Starting epoch 2673/4000.
# Epoch finished ! Loss: 0.17414621114730836
# Starting epoch 2674/4000.
# Epoch finished ! Loss: 0.16970286816358565
# Starting epoch 2675/4000.
# Epoch finished ! Loss: 0.17344742119312287
# Starting epoch 2676/4000.
# Epoch finished ! Loss: 0.1736995741724968
# Starting epoch 2677/4000.
# Epoch finished ! Loss: 0.1759062647819519
# Starting epoch 2678/4000.
# Epoch finished ! Loss: 0.16832707077264786
# Starting epoch 2679/4000.
# Epoch finished ! Loss: 0.16972566843032838
# Starting epoch 2680/4000.
# Epoch finished ! Loss: 0.17266839742660522
# Starting epoch 2681/4000.
# Epoch finished ! Loss: 0.1787150263786316
# Starting epoch 2682/4000.
# Epoch finished ! Loss: 0.17114801704883575
# Starting epoch 2683/4000.
# Epoch finished ! Loss: 0.172598697245121
# Starting epoch 2684/4000.
# Epoch finished ! Loss: 0.17607951909303665
# Starting epoch 2685/4000.
# Epoch finished ! Loss: 0.17224644720554352
# Starting epoch 2686/4000.
# Epoch finished ! Loss: 0.17513174563646317
# Starting epoch 2687/4000.
# Epoch finished ! Loss: 0.1744450658559799
# Starting epoch 2688/4000.
# Epoch finished ! Loss: 0.1749351754784584
# Starting epoch 2689/4000.
# Epoch finished ! Loss: 0.1750415235757828
# Starting epoch 2690/4000.
# Epoch finished ! Loss: 0.17730536162853242
# Starting epoch 2691/4000.
# Epoch finished ! Loss: 0.17319308817386628
# Starting epoch 2692/4000.
# Epoch finished ! Loss: 0.17819197624921798
# Starting epoch 2693/4000.
# Epoch finished ! Loss: 0.17608466893434524
# Starting epoch 2694/4000.
# Epoch finished ! Loss: 0.17597092539072037
# Starting epoch 2695/4000.
# Epoch finished ! Loss: 0.1671363651752472
# Starting epoch 2696/4000.
# Epoch finished ! Loss: 0.169844089448452
# Starting epoch 2697/4000.
# Epoch finished ! Loss: 0.171959525346756
# Starting epoch 2698/4000.
# Epoch finished ! Loss: 0.16740640997886658
# Starting epoch 2699/4000.
# Epoch finished ! Loss: 0.17683668732643126
# Starting epoch 2700/4000.
# Epoch finished ! Loss: 0.1749907210469246
# Starting epoch 2701/4000.
# Epoch finished ! Loss: 0.17020283490419388
# Starting epoch 2702/4000.
# Epoch finished ! Loss: 0.17547038197517395
# Starting epoch 2703/4000.
# Epoch finished ! Loss: 0.17040500789880753
# Starting epoch 2704/4000.
# Epoch finished ! Loss: 0.16900457739830016
# Starting epoch 2705/4000.
# Epoch finished ! Loss: 0.16931413412094115
# Starting epoch 2706/4000.
# Epoch finished ! Loss: 0.17106920778751372
# Starting epoch 2707/4000.
# Epoch finished ! Loss: 0.17753157168626785
# Starting epoch 2708/4000.
# Epoch finished ! Loss: 0.1752600133419037
# Starting epoch 2709/4000.
# Epoch finished ! Loss: 0.17409510612487794
# Starting epoch 2710/4000.

# %%
if os.path.isdir(model_save_path):
            torch.save(model.state_dict(),model_save_path + 'sony{}.pth'.format(epoch + 1))
else:
    os.makedirs(model_save_path, exist_ok=True)
    torch.save(model.state_dict(),model_save_path + 'sony{}.pth'.format(epoch + 1))
