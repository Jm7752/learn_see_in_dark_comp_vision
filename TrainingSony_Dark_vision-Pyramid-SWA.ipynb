# %%
from __future__ import division
import os, time
import numpy as np
import glob
import torch
import torch.nn as nn
import torch.nn.functional as F
import random
import sys
import os
from optparse import OptionParser
import numpy as np
from torch import optim
from PIL import Image
from torch.autograd import Function, Variable
import matplotlib.pyplot as plt
from torchvision import transforms
from torch.utils.data import Dataset
import cv2
import glob
import pickle
from tqdm import tqdm
import rawpy
# %matplotlib inline

input_dir = './Dataset/Sony/short/'
gt_dir = './Dataset/Sony/long/'

result_dir = './results_SWA/'
model_save_path = './results_SWA/net_weights/'
if os.path.isdir(model_save_path) is not True:
    os.makedirs(model_save_path, exist_ok=True)

# %%
if torch.cuda.is_available():
    deviceTag = torch.device('cuda')
else:
    deviceTag = torch.device('cpu')
print(deviceTag)
# Out:
# cuda

# %%
from utils.swa import SWA

# %% [markdown]
# # LOAD DATASET

# %%
# get train IDs
train_fns = glob.glob(gt_dir + '0*.ARW')
train_ids = [int(os.path.basename(train_fn)[0:5]) for train_fn in train_fns]

ps = 512  # patch size for training
save_freq = 500

DEBUG = 0
if DEBUG == 1:
    save_freq = 2
    train_ids = train_ids[0:5]

# %% [markdown]
# # UNET MODULES

# %%
class conv_lrelu(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(conv_lrelu, self).__init__()
        self.conv = nn.Sequential(nn.Conv2d(in_ch,out_ch,3, padding = 1),nn.LeakyReLU())

    def forward(self, x):
        x = self.conv(x)
        return x
    
class down(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(down, self).__init__()
        self.conv1 = conv_lrelu(in_ch,out_ch)
        self.conv2 = conv_lrelu(out_ch,out_ch)
        self.down =  nn.MaxPool2d((2,2))
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.down(x)
        return x
    

class up(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(up, self).__init__()       
        self.up =  nn.UpsamplingBilinear2d(scale_factor = 2)
        self.conv1 = conv_lrelu(in_ch,out_ch) 
        self.conv2 = conv_lrelu(out_ch,out_ch) 

    def forward(self, x1, x2):
        x1 = self.up(x1)
        x = torch.cat([x2, x1], dim=1)
        x = self.conv1(x)
        x = self.conv2(x)
        return x

class UNet(nn.Module):
    def __init__(self, in_ch = 4, CH_PER_SCALE = [32,64,128,256,512], out_ch = 12):
        super(UNet, self).__init__()
        self.inc = conv_lrelu(in_ch, CH_PER_SCALE[0])
        self.inc2 = conv_lrelu(CH_PER_SCALE[0], CH_PER_SCALE[0])
        self.down1 = down(CH_PER_SCALE[0], CH_PER_SCALE[1]) 
        self.down2 = down(CH_PER_SCALE[1],CH_PER_SCALE[2])
        self.down3 = down(CH_PER_SCALE[2],CH_PER_SCALE[3])                
        self.down4 = down(CH_PER_SCALE[3],CH_PER_SCALE[4])                
        self.up1 = up(CH_PER_SCALE[4]+CH_PER_SCALE[3],CH_PER_SCALE[3])
        self.up2 = up(CH_PER_SCALE[3]+CH_PER_SCALE[2],CH_PER_SCALE[2])
        self.up3 = up(CH_PER_SCALE[2]+CH_PER_SCALE[1],CH_PER_SCALE[1])
        self.up4 = up(CH_PER_SCALE[1]+CH_PER_SCALE[0],CH_PER_SCALE[0])
        self.outc = nn.Conv2d(CH_PER_SCALE[0], out_ch, 1, padding = 0)

    def forward(self, x):
        x0 = self.inc(x)
        x0 = self.inc2(x0)
        x1 = self.down1(x0)
        x2 = self.down2(x1)
        x3 = self.down3(x2)
        x4 = self.down4(x3)
        x3_up = self.up1(x4,x3)
        x2_up = self.up2(x3_up,x2)
        x1_up = self.up3(x2_up,x1)
        out = self.up4(x1_up,x0)
        out = self.outc(out)
#         out = F.pixel_shuffle(out,2) ## Paper final step rearranges 12 channes to 3 RGB channels
#         out = F.hardtanh(out, min_val=0, max_val=1) #Clamp the top and bottom to 0,1 since pixels can only be in this value
        return out
    
class PRIDNet(nn.Module):
    def __init__(self, in_ch = 4, out_ch = 12):
        super(PRIDNet, self).__init__()
        self.feature_extraction = nn.Sequential(conv_lrelu(in_ch, 32), *[conv_lrelu(32, 32) for i in range(3)])
        self.unet0 = UNet(in_ch = 32, out_ch = 12)
        self.unet1 = UNet(in_ch = 32, out_ch = 12)
        self.unet2 = UNet(in_ch = 32, out_ch = 12)
        self.unet3 = UNet(in_ch = 32, out_ch = 12)
        self.unet4 = UNet(in_ch = 32, out_ch = 12)
        self.avgpool1 = nn.AvgPool2d((2,2))
        self.avgpool2 = nn.AvgPool2d((4,4))
        self.avgpool3 = nn.AvgPool2d((8,8))
        self.avgpool4 = nn.AvgPool2d((16,16))
        self.up4 =  nn.UpsamplingBilinear2d(scale_factor = 16)
        self.up3 =  nn.UpsamplingBilinear2d(scale_factor = 8)
        self.up2 =  nn.UpsamplingBilinear2d(scale_factor = 4)
        self.up1 =  nn.UpsamplingBilinear2d(scale_factor = 2)
        self.out =  nn.Conv2d(32+12*5, out_ch, 1, padding = 0)

    def forward(self, x):
        x_feat = self.feature_extraction(x)
        x0 = self.unet0(x_feat)
        x1 = self.up1(self.unet1(self.avgpool1(x_feat)))
        x2 = self.up2(self.unet2(self.avgpool2(x_feat)))
        x3 = self.up3(self.unet3(self.avgpool3(x_feat)))
        x4 = self.up4(self.unet4(self.avgpool4(x_feat)))
        x_unet_all = torch.cat([x_feat,x0,x1,x2,x3,x4], axis = 1)
        out = self.out(x_unet_all)
        
        out = F.pixel_shuffle(out,2) ## Paper final step rearranges 12 channes to 3 RGB channels
        out = F.hardtanh(out, min_val=0, max_val=1) #Clamp the top and bottom to 0,1 since pixels can only be in this value
        return out
    
    def load_my_state_dict(self, state_dict):
        own_state = self.state_dict()
        for name, param in state_dict.items():
            if name not in own_state:
                 continue
            #if isinstance(param, self.Parameter):
            else:
                # backwards compatibility for serialized parameters
                param = param.data
            own_state[name].copy_(param)

# %% [markdown]
# # Helper Functions for packing raw and saving images

# %%
def pack_raw(raw):
    # pack Bayer image to 4 channels
    im = raw.raw_image_visible.astype(np.float32)
    im = np.maximum(im - 512, 0) / (16383 - 512)  # subtract the black level

    im = np.expand_dims(im, axis=2)
    img_shape = im.shape
    H = img_shape[0]
    W = img_shape[1]

    out = np.concatenate((im[0:H:2, 0:W:2, :],
                          im[0:H:2, 1:W:2, :],
                          im[1:H:2, 1:W:2, :],
                          im[1:H:2, 0:W:2, :]), axis=2)
    return out

# %%
# Raw data takes long time to load. Keep them in memory after loaded.
gt_images = [None] * 6000
input_images = {}
input_images['300'] = [None] * len(train_ids)
input_images['250'] = [None] * len(train_ids)
input_images['100'] = [None] * len(train_ids)

g_loss = np.zeros((5000, 1))

allfolders = glob.glob(result_dir + '*0')

for folder in allfolders:
    lastepoch = np.maximum(epochs, int(folder[-4:]))

# %% [markdown]
# # Training

# %%
model = PRIDNet()
model = model.cuda()
model = model.train()

# %%
def process_img(input_raw_img, model, ratio):
    ## Process image(s) using the given model
    # input_raw_img: numpy array, dimension: (Batch,Height,Width,Channel)
    # ratio: numpy array, dimension: (Batch,)
    model.eval();
    model.to(deviceTag)
    ratio = ratio.reshape(ratio.shape[0],1,1,1)
    input_raw_img = np.transpose(input_raw_img, [0,3,1,2]).astype('float32')*ratio
    input_tensor = torch.from_numpy(input_raw_img.copy()).float().to(deviceTag)
    with torch.no_grad():
        output_tensor = model(input_tensor)
    output_img = output_tensor.cpu().numpy()
    output_img = np.transpose(output_img, [0,2,3,1])
    
    return output_img
    
def validate(model, input_list, gt_list, block_size = None, batch_size = 8):
    assert len(input_list) == len(gt_list)
    
    model.eval();
    PSNR_list = []
    
    for i in range(len(input_list)//batch_size):
        if i%10 == 0:
            print(i)
        input_raw_img_batch = []
        gt_img_batch = []
        ratio_batch = []
        for b in range(batch_size):
            if i*batch_size+b < len(input_list):
                in_path = input_list[i*batch_size+b]
                gt_path = gt_list[i*batch_size+b]
            else:
                break
            in_fn = os.path.basename(in_path)
            gt_fn = os.path.basename(gt_path)
            in_exposure = float(in_fn[9:-5])
            gt_exposure = float(gt_fn[9:-5])
            ratio = min(gt_exposure / in_exposure, 300)
        
            raw = rawpy.imread(in_path)
            input_raw_img = pack_raw(raw)
            
            gt_raw = rawpy.imread(gt_path)
            gt_img = gt_raw.postprocess(use_camera_wb=True, half_size=False, no_auto_bright=True, output_bps=16)
            gt_img = np.float32(gt_img / 65535.0)
            
            if block_size is not None:
                i_cut, j_cut = np.random.randint(0,input_raw_img.shape[0]-block_size), np.random.randint(0,input_raw_img.shape[1]-block_size)
                gt_img = gt_img[i_cut*2:i_cut*2+block_size*2, j_cut*2:j_cut*2+block_size*2, :]
                input_raw_img = input_raw_img[i_cut:i_cut+block_size, j_cut:j_cut+block_size, :]
            
            ratio_batch.append(ratio)
            input_raw_img_batch.append(input_raw_img)
            gt_img_batch.append(gt_img)
        
        input_raw_img_batch = np.array(input_raw_img_batch)
        ratio_batch = np.array(ratio_batch)
        gt_img_batch = np.array(gt_img_batch)
        
        output_img_batch = process_img(input_raw_img_batch, model, ratio_batch)
        plt.figure()
        plt.imshow(gt_img_batch[0,:,:,:])
        plt.title("Ground Truth")
        plt.figure()
        plt.imshow(output_img_batch[0,:,:,:])
        plt.title("Predicted patch")
        MSE = np.mean((output_img_batch.reshape(output_img_batch.shape[0],-1) - gt_img_batch.reshape(gt_img_batch.shape[0],-1))**2, axis = 1)
        PSNR_batch = 10*np.log10(1/MSE)
        PSNR_list.append(list(PSNR_batch))
    
    Val_PSNR = np.mean(PSNR_list)
        
    return Val_PSNR

# %%
learning_rate = 1e-4
batch_num = 4;
base_opt = optim.SGD(model.parameters(), lr=learning_rate)
optimizer = SWA(base_opt, swa_start=1000, swa_freq=10, swa_lr=0.05)
scheduler = optim.lr_scheduler.StepLR(base_opt, step_size=2000, gamma=0.1) #Step Scheduler. 
criterion = nn.MSELoss()

Start_epoch = 0
epochs = 4000
TrainingLossData = np.zeros(epochs)

for epoch in range(Start_epoch, Start_epoch+epochs):
    print('Starting epoch {}/{}.'.format(epoch + 1, epochs))
    epoch_loss = 0 ## Set Epoch Loss
    count = 0;
    batches_processed = 0
    ##This version has a batch size of 1. In the future conside increasing batchsize
    for ind in np.random.permutation(len(train_ids)):    
        # get the path from image id
        train_id = train_ids[ind]
        in_files = glob.glob(input_dir + '%05d_00*.ARW' % train_id)
        in_path = in_files[np.random.random_integers(0, len(in_files) - 1)]
        in_fn = os.path.basename(in_path)

        gt_files = glob.glob(gt_dir + '%05d_00*.ARW' % train_id)
        gt_path = gt_files[0]
        gt_fn = os.path.basename(gt_path)
        in_exposure = float(in_fn[9:-5])
        gt_exposure = float(gt_fn[9:-5])
        ratio = min(gt_exposure / in_exposure, 300)

        st = time.time()

        if input_images[str(ratio)[0:3]][ind] is None:
            raw = rawpy.imread(in_path)
            input_images[str(ratio)[0:3]][ind] = np.expand_dims(pack_raw(raw), axis=0) * ratio

            gt_raw = rawpy.imread(gt_path)
            im = gt_raw.postprocess(use_camera_wb=True, half_size=False, no_auto_bright=True, output_bps=16)
            gt_images[ind] = np.expand_dims(np.float32(im / 65535.0), axis=0)

        # crop
        H = input_images[str(ratio)[0:3]][ind].shape[1]
        W = input_images[str(ratio)[0:3]][ind].shape[2]

        xx = np.random.randint(0, W - ps)
        yy = np.random.randint(0, H - ps)
        input_patch = input_images[str(ratio)[0:3]][ind][:, yy:yy + ps, xx:xx + ps, :]
        gt_patch = gt_images[ind][:, yy * 2:yy * 2 + ps * 2, xx * 2:xx * 2 + ps * 2, :]

        if np.random.randint(2, size=1)[0] == 1:  # random flip
            input_patch = np.flip(input_patch, axis=1)
            gt_patch = np.flip(gt_patch, axis=1)
        if np.random.randint(2, size=1)[0] == 1:
            input_patch = np.flip(input_patch, axis=2)
            gt_patch = np.flip(gt_patch, axis=2)
        if np.random.randint(2, size=1)[0] == 1:  # random transpose
            input_patch = np.transpose(input_patch, (0, 2, 1, 3))
            gt_patch = np.transpose(gt_patch, (0, 2, 1, 3))
        #(1, 512, 512, 4)
        #(1, 1024, 1024, 3)
        input_patch = np.transpose(input_patch, (0,3,1,2))
        input_patch = torch.from_numpy(input_patch.copy()).cuda()
        gt_patch = np.transpose(gt_patch, (0,3,1,2))
        gt_patch = torch.from_numpy(gt_patch.copy()).cuda()
        ##Batch concatenation
        if count%(batch_num)==0:
            input_patch_all = input_patch
            gt_patch_all = gt_patch
        else:
            input_patch_all = torch.cat([input_patch_all, input_patch], dim=0)
            gt_patch_all = torch.cat([gt_patch_all, gt_patch], dim=0)
        ##Every N batches we ship it back 
        if count%(batch_num)==batch_num-1:
            #print(input_patch_all.shape)
            img_pred = model.forward(input_patch_all)
            loss = criterion(img_pred, gt_patch_all)
            epoch_loss += loss.item()
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            batches_processed += 1
            ##print(epoch_loss/count);
        count = count +1
    scheduler.step()
    print('Epoch finished ! Loss: {}'.format(epoch_loss / batches_processed))
    if epoch == 0:
        trainF= open(result_dir+"TrainingEpoch.txt","w+")
        trainF.write('Epoch,Train_loss\n')
        trainF.write('{},{}\n'.format(epoch, epoch_loss / batches_processed))
        trainF.close()
    else:
        trainF= open(result_dir+"TrainingEpoch.txt","a")
        trainF.write('{},{}\n'.format(epoch, epoch_loss / batches_processed))
        trainF.close()
    TrainingLossData[epoch] = epoch_loss / batches_processed ## Save for plotting
    ################################################ [TODO] ###################################################
    # Perform validation with eval_net() on the validation data
    # Save the model after every 10 epochs. This save our Memory on HPC.
    ##Save Top results after 95%
    if epoch > epochs*0.95:
        torch.save(model.state_dict(),model_save_path + 'sony{}.pth'.format(epoch + 1))
    if epoch%99 == 0:
        torch.save(model.state_dict(),model_save_path + 'sony{}.pth'.format(epoch + 1))

optimizer.swap_swa_sgd()
torch.save(model.state_dict(),model_save_path + 'sony{}.pth'.format(epoch + 1))
# Out:
# Starting epoch 1/4000.
# <ipython-input-10-9bd6848c6386>:22: DeprecationWarning: This function is deprecated. Please call randint(0, 0 + 1) instead
#   in_path = in_files[np.random.random_integers(0, len(in_files) - 1)]
# <ipython-input-10-9bd6848c6386>:22: DeprecationWarning: This function is deprecated. Please call randint(0, 1 + 1) instead
#   in_path = in_files[np.random.random_integers(0, len(in_files) - 1)]
# <ipython-input-10-9bd6848c6386>:22: DeprecationWarning: This function is deprecated. Please call randint(0, 2 + 1) instead
#   in_path = in_files[np.random.random_integers(0, len(in_files) - 1)]
# Epoch finished ! Loss: 0.08446125553455204
# Starting epoch 2/4000.
# Epoch finished ! Loss: 0.08514510178938509
# Starting epoch 3/4000.
# Epoch finished ! Loss: 0.08160317400470377
# Starting epoch 4/4000.
# Epoch finished ! Loss: 0.08639021832495927
# Starting epoch 5/4000.
# Epoch finished ! Loss: 0.08197938054800033
# Starting epoch 6/4000.
# Epoch finished ! Loss: 0.08757441475754604
# Starting epoch 7/4000.
# Epoch finished ! Loss: 0.08554771190974861
# Starting epoch 8/4000.
# Epoch finished ! Loss: 0.08134236671030522
# Starting epoch 9/4000.
# Epoch finished ! Loss: 0.07823340981267393
# Starting epoch 10/4000.
# Epoch finished ! Loss: 0.08552727324422449
# Starting epoch 11/4000.
# Epoch finished ! Loss: 0.08355004640761762
# Starting epoch 12/4000.
# Epoch finished ! Loss: 0.07384061184711754
# Starting epoch 13/4000.
# Epoch finished ! Loss: 0.07670602169819177
# Starting epoch 14/4000.
# Epoch finished ! Loss: 0.0822586442809552
# Starting epoch 15/4000.
# Epoch finished ! Loss: 0.07924061589874327
# Starting epoch 16/4000.
# Epoch finished ! Loss: 0.07998641161248088
# Starting epoch 17/4000.
# Epoch finished ! Loss: 0.07912024375982582
# Starting epoch 18/4000.
# Epoch finished ! Loss: 0.08041095645166933
# Starting epoch 19/4000.
# Epoch finished ! Loss: 0.08412210210226476
# Starting epoch 20/4000.
# Epoch finished ! Loss: 0.08664529109373689
# Starting epoch 21/4000.
# Epoch finished ! Loss: 0.08357875775545835
# Starting epoch 22/4000.
# Epoch finished ! Loss: 0.08516555167734623
# Starting epoch 23/4000.
# Epoch finished ! Loss: 0.07789804711937905
# Starting epoch 24/4000.
# Epoch finished ! Loss: 0.08565155486576259
# Starting epoch 25/4000.
# Epoch finished ! Loss: 0.08297442467883229
# Starting epoch 26/4000.
# Epoch finished ! Loss: 0.07180466610006989
# Starting epoch 27/4000.
# Epoch finished ! Loss: 0.07334758746437728
# Starting epoch 28/4000.
# Epoch finished ! Loss: 0.06628434848971665
# Starting epoch 29/4000.
# Epoch finished ! Loss: 0.06373285287991166
# Starting epoch 30/4000.
# Epoch finished ! Loss: 0.06612579091452062
# Starting epoch 31/4000.
# Epoch finished ! Loss: 0.06482347501441836
# Starting epoch 32/4000.
# Epoch finished ! Loss: 0.06742549031041563
# Starting epoch 33/4000.
# Epoch finished ! Loss: 0.06680365931242704
# Starting epoch 34/4000.
# Epoch finished ! Loss: 0.07075933385640383
# Starting epoch 35/4000.
# Epoch finished ! Loss: 0.0700096174608916
# Starting epoch 36/4000.
# Epoch finished ! Loss: 0.06251738355495036
# Starting epoch 37/4000.
# Epoch finished ! Loss: 0.06363731203600764
# Starting epoch 38/4000.
# Epoch finished ! Loss: 0.0641763580031693
# Starting epoch 39/4000.
# Epoch finished ! Loss: 0.056231187842786315
# Starting epoch 40/4000.
# Epoch finished ! Loss: 0.05233671292662621
# Starting epoch 41/4000.
# Epoch finished ! Loss: 0.05104365353472531
# Starting epoch 42/4000.
# Epoch finished ! Loss: 0.04115496543236077
# Starting epoch 43/4000.
# Epoch finished ! Loss: 0.03499593120068312
# Starting epoch 44/4000.
# Epoch finished ! Loss: 0.030031831050291658
# Starting epoch 45/4000.
# Epoch finished ! Loss: 0.025798821356147528
# Starting epoch 46/4000.
# Epoch finished ! Loss: 0.023553595202974974
# Starting epoch 47/4000.
# Epoch finished ! Loss: 0.023990055941976608
# Starting epoch 48/4000.
# Epoch finished ! Loss: 0.023440512199886143
# Starting epoch 49/4000.
# Epoch finished ! Loss: 0.022659156797453762
# Starting epoch 50/4000.
# Epoch finished ! Loss: 0.022800817713141443
# Starting epoch 51/4000.
# Epoch finished ! Loss: 0.024590103491209447
# Starting epoch 52/4000.
# Epoch finished ! Loss: 0.02341363998129964
# Starting epoch 53/4000.
# Epoch finished ! Loss: 0.02280577684286982
# Starting epoch 54/4000.
# Epoch finished ! Loss: 0.023181502579245717
# Starting epoch 55/4000.
# Epoch finished ! Loss: 0.022725101560354233
# Starting epoch 56/4000.
# Epoch finished ! Loss: 0.023139135097153485
# Starting epoch 57/4000.
# Epoch finished ! Loss: 0.021357369842007756
# Starting epoch 58/4000.
# Epoch finished ! Loss: 0.021457878896035253
# Starting epoch 59/4000.
# Epoch finished ! Loss: 0.02156220900360495
# Starting epoch 60/4000.
# Epoch finished ! Loss: 0.020932645094580947
# Starting epoch 61/4000.
# Epoch finished ! Loss: 0.02149330811807886
# Starting epoch 62/4000.
# Epoch finished ! Loss: 0.0215828537940979
# Starting epoch 63/4000.
# Epoch finished ! Loss: 0.02187655696179718
# Starting epoch 64/4000.
# Epoch finished ! Loss: 0.021028910984750838
# Starting epoch 65/4000.
# Epoch finished ! Loss: 0.02154669229639694
# Starting epoch 66/4000.
# Epoch finished ! Loss: 0.022832027217373253
# Starting epoch 67/4000.
# Epoch finished ! Loss: 0.02172599055338651
# Starting epoch 68/4000.
# Epoch finished ! Loss: 0.02203725352883339
# Starting epoch 69/4000.
# Epoch finished ! Loss: 0.021014078380540015
# Starting epoch 70/4000.
# Epoch finished ! Loss: 0.022211570478975772
# Starting epoch 71/4000.
# Epoch finished ! Loss: 0.019912698352709413
# Starting epoch 72/4000.
# Epoch finished ! Loss: 0.021256877458654344
# Starting epoch 73/4000.
# Epoch finished ! Loss: 0.02111077359877527
# Starting epoch 74/4000.
# Epoch finished ! Loss: 0.020255195279605686
# Starting epoch 75/4000.
# Epoch finished ! Loss: 0.020723536796867847
# Starting epoch 76/4000.
# Epoch finished ! Loss: 0.01979089214000851
# Starting epoch 77/4000.
# Epoch finished ! Loss: 0.019357699993997814
# Starting epoch 78/4000.
# Epoch finished ! Loss: 0.01921714978525415
# Starting epoch 79/4000.
# Epoch finished ! Loss: 0.02057722266763449
# Starting epoch 80/4000.
# Epoch finished ! Loss: 0.019637436361517758
# Starting epoch 81/4000.
# Epoch finished ! Loss: 0.020131696877069772
# Starting epoch 82/4000.
# Epoch finished ! Loss: 0.021505464660003783
# Starting epoch 83/4000.
# Epoch finished ! Loss: 0.02040416862582788
# Starting epoch 84/4000.
# Epoch finished ! Loss: 0.019220608787145467
# Starting epoch 85/4000.
# Epoch finished ! Loss: 0.01870518869254738
# Starting epoch 86/4000.
# Epoch finished ! Loss: 0.01784547322895378
# Starting epoch 87/4000.
# Epoch finished ! Loss: 0.0190584733732976
# Starting epoch 88/4000.
# Epoch finished ! Loss: 0.019994881562888624
# Starting epoch 89/4000.
# Epoch finished ! Loss: 0.0202075605513528
# Starting epoch 90/4000.
# Epoch finished ! Loss: 0.020325006218627095
# Starting epoch 91/4000.
# Epoch finished ! Loss: 0.018143434613011777
# Starting epoch 92/4000.
# Epoch finished ! Loss: 0.019841151044238357
# Starting epoch 93/4000.
# Epoch finished ! Loss: 0.018661627802066504
# Starting epoch 94/4000.
# Epoch finished ! Loss: 0.020087855844758452
# Starting epoch 95/4000.
# Epoch finished ! Loss: 0.01956800714833662
# Starting epoch 96/4000.
# Epoch finished ! Loss: 0.019062590110115706
# Starting epoch 97/4000.
# Epoch finished ! Loss: 0.020701073459349573
# Starting epoch 98/4000.
# Epoch finished ! Loss: 0.018078614596743137
# Starting epoch 99/4000.
# Epoch finished ! Loss: 0.01925471950089559
# Starting epoch 100/4000.
# Epoch finished ! Loss: 0.018056003854144364
# Starting epoch 101/4000.
# Epoch finished ! Loss: 0.020025379944127054
# Starting epoch 102/4000.
# Epoch finished ! Loss: 0.01913389372639358
# Starting epoch 103/4000.
# Epoch finished ! Loss: 0.019542657653801143
# Starting epoch 104/4000.
# Epoch finished ! Loss: 0.019638259056955577
# Starting epoch 105/4000.
# Epoch finished ! Loss: 0.01828415271593258
# Starting epoch 106/4000.
# Epoch finished ! Loss: 0.01851697309175506
# Starting epoch 107/4000.
# Epoch finished ! Loss: 0.019184051651973278
# Starting epoch 108/4000.
# Epoch finished ! Loss: 0.019408892653882504
# Starting epoch 109/4000.
# Epoch finished ! Loss: 0.020432320167310537
# Starting epoch 110/4000.
# Epoch finished ! Loss: 0.01974738242570311
# Starting epoch 111/4000.
# Epoch finished ! Loss: 0.017991283780429513
# Starting epoch 112/4000.
# Epoch finished ! Loss: 0.019546428590547293
# Starting epoch 113/4000.
# Epoch finished ! Loss: 0.019080079591367392
# Starting epoch 114/4000.
# Epoch finished ! Loss: 0.0187046492472291
# Starting epoch 115/4000.
# Epoch finished ! Loss: 0.018862730322871356
# Starting epoch 116/4000.
# Epoch finished ! Loss: 0.019716805208008736
# Starting epoch 117/4000.
# Epoch finished ! Loss: 0.01952932346612215
# Starting epoch 118/4000.
# Epoch finished ! Loss: 0.02044448347296566
# Starting epoch 119/4000.
# Epoch finished ! Loss: 0.01888350519584492
# Starting epoch 120/4000.
# Epoch finished ! Loss: 0.018387604237068443
# Starting epoch 121/4000.
# Epoch finished ! Loss: 0.01893564051715657
# Starting epoch 122/4000.
# Epoch finished ! Loss: 0.019857347151264547
# Starting epoch 123/4000.
# Epoch finished ! Loss: 0.018764441751409323
# Starting epoch 124/4000.
# Epoch finished ! Loss: 0.019239833927713335
# Starting epoch 125/4000.
# Epoch finished ! Loss: 0.0191692448919639
# Starting epoch 126/4000.
# Epoch finished ! Loss: 0.019322043959982695
# Starting epoch 127/4000.
# Epoch finished ! Loss: 0.020204559434205294
# Starting epoch 128/4000.
# Epoch finished ! Loss: 0.01832672767341137
# Starting epoch 129/4000.
# Epoch finished ! Loss: 0.019791716989129782
# Starting epoch 130/4000.
# Epoch finished ! Loss: 0.01727230045944452
# Starting epoch 131/4000.
# Epoch finished ! Loss: 0.019860619597602637
# Starting epoch 132/4000.
# Epoch finished ! Loss: 0.019500655552837996
# Starting epoch 133/4000.
# Epoch finished ! Loss: 0.019693822809495033
# Starting epoch 134/4000.
# Epoch finished ! Loss: 0.01902453196235001
# Starting epoch 135/4000.
# Epoch finished ! Loss: 0.018019898142665625
# Starting epoch 136/4000.
# Epoch finished ! Loss: 0.01983831328107044
# Starting epoch 137/4000.
# Epoch finished ! Loss: 0.02012584995245561
# Starting epoch 138/4000.
# Epoch finished ! Loss: 0.018556232820264994
# Starting epoch 139/4000.
# Epoch finished ! Loss: 0.018950121372472494
# Starting epoch 140/4000.
# Epoch finished ! Loss: 0.02004096661694348
# Starting epoch 141/4000.
# Epoch finished ! Loss: 0.019717725948430596
# Starting epoch 142/4000.
# Epoch finished ! Loss: 0.019419342814944684
# Starting epoch 143/4000.
# Epoch finished ! Loss: 0.01838672598823905
# Starting epoch 144/4000.
# Epoch finished ! Loss: 0.0194969009491615
# Starting epoch 145/4000.
# Epoch finished ! Loss: 0.018800212850328533
# Starting epoch 146/4000.
# Epoch finished ! Loss: 0.019315082544926553
# Starting epoch 147/4000.
# Epoch finished ! Loss: 0.019994881632737816
# Starting epoch 148/4000.
# Epoch finished ! Loss: 0.019103695114608854
# Starting epoch 149/4000.
# Epoch finished ! Loss: 0.01838741551619023
# Starting epoch 150/4000.
# Epoch finished ! Loss: 0.019786829059012235
# Starting epoch 151/4000.
# Epoch finished ! Loss: 0.018574971915222706
# Starting epoch 152/4000.
# Epoch finished ! Loss: 0.01935123953735456
# Starting epoch 153/4000.
# Epoch finished ! Loss: 0.01945110025117174
# Starting epoch 154/4000.
# Epoch finished ! Loss: 0.01924194626044482
# Starting epoch 155/4000.
# Epoch finished ! Loss: 0.01958335661329329
# Starting epoch 156/4000.
# Epoch finished ! Loss: 0.01881337552331388
# Starting epoch 157/4000.
# Epoch finished ! Loss: 0.02042236819397658
# Starting epoch 158/4000.
# Epoch finished ! Loss: 0.018921130080707373
# Starting epoch 159/4000.
# Epoch finished ! Loss: 0.019984045601449906
# Starting epoch 160/4000.
# Epoch finished ! Loss: 0.019049411173909903
# Starting epoch 161/4000.
# Epoch finished ! Loss: 0.020406176336109638
# Starting epoch 162/4000.
# Epoch finished ! Loss: 0.0196140669984743
# Starting epoch 163/4000.
# Epoch finished ! Loss: 0.017999242071527987
# Starting epoch 164/4000.
# Epoch finished ! Loss: 0.019897308747749774
# Starting epoch 165/4000.
# Epoch finished ! Loss: 0.019973093143198638
# Starting epoch 166/4000.
# Epoch finished ! Loss: 0.018491143349092454
# Starting epoch 167/4000.
# Epoch finished ! Loss: 0.02002358135068789
# Starting epoch 168/4000.
# Epoch finished ! Loss: 0.019402588543016464
# Starting epoch 169/4000.
# Epoch finished ! Loss: 0.018784167349804193
# Starting epoch 170/4000.
# Epoch finished ! Loss: 0.018737930827774106
# Starting epoch 171/4000.
# Epoch finished ! Loss: 0.020607726299203932
# Starting epoch 172/4000.
# Epoch finished ! Loss: 0.019204755453392862
# Starting epoch 173/4000.
# Epoch finished ! Loss: 0.01985520775197074
# Starting epoch 174/4000.
# Epoch finished ! Loss: 0.02021897453814745
# Starting epoch 175/4000.
# Epoch finished ! Loss: 0.02022949755191803
# Starting epoch 176/4000.
# Epoch finished ! Loss: 0.01731205256655812
# Starting epoch 177/4000.
# Epoch finished ! Loss: 0.019290321390144527
# Starting epoch 178/4000.
# Epoch finished ! Loss: 0.020706147060263903
# Starting epoch 179/4000.
# Epoch finished ! Loss: 0.01914713243022561
# Starting epoch 180/4000.
# Epoch finished ! Loss: 0.019908899534493686
# Starting epoch 181/4000.
# Epoch finished ! Loss: 0.019459137436933817
# Starting epoch 182/4000.
# Epoch finished ! Loss: 0.020025860029272737
# Starting epoch 183/4000.
# Epoch finished ! Loss: 0.019438316044397653
# Starting epoch 184/4000.
# Epoch finished ! Loss: 0.019090083870105447
# Starting epoch 185/4000.
# Epoch finished ! Loss: 0.01898576244711876
# Starting epoch 186/4000.
# Epoch finished ! Loss: 0.018917415069881826
# Starting epoch 187/4000.
# Epoch finished ! Loss: 0.019063395808916538
# Starting epoch 188/4000.
# Epoch finished ! Loss: 0.0195809735218063
# Starting epoch 189/4000.
# Epoch finished ! Loss: 0.020040036900900303
# Starting epoch 190/4000.
# Epoch finished ! Loss: 0.0180602828389965
# Starting epoch 191/4000.
# Epoch finished ! Loss: 0.019232944899704306
# Starting epoch 192/4000.
# Epoch finished ! Loss: 0.018737931386567652
# Starting epoch 193/4000.
# Epoch finished ! Loss: 0.019137870834674685
# Starting epoch 194/4000.
# Epoch finished ! Loss: 0.019514244655147193
# Starting epoch 195/4000.
# Epoch finished ! Loss: 0.01825955417007208
# Starting epoch 196/4000.
# Epoch finished ! Loss: 0.019280053302645685
# Starting epoch 197/4000.
# Epoch finished ! Loss: 0.01935183823807165
# Starting epoch 198/4000.
# Epoch finished ! Loss: 0.019667385052889584
# Starting epoch 199/4000.
# Epoch finished ! Loss: 0.01924076003488153
# Starting epoch 200/4000.
# Epoch finished ! Loss: 0.01950705733615905
# Starting epoch 201/4000.
# Epoch finished ! Loss: 0.019077696732711046
# Starting epoch 202/4000.
# Epoch finished ! Loss: 0.020063799410127103
# Starting epoch 203/4000.
# Epoch finished ! Loss: 0.018926054460462183
# Starting epoch 204/4000.
# Epoch finished ! Loss: 0.019206734863109885
# Starting epoch 205/4000.
# Epoch finished ! Loss: 0.019299025053624064
# Starting epoch 206/4000.
# Epoch finished ! Loss: 0.018899886787403376
# Starting epoch 207/4000.
# Epoch finished ! Loss: 0.019263455516193063
# Starting epoch 208/4000.
# Epoch finished ! Loss: 0.019849878409877418
# Starting epoch 209/4000.
# Epoch finished ! Loss: 0.017897454905323684
# Starting epoch 210/4000.
# Epoch finished ! Loss: 0.019293590390589088
# Starting epoch 211/4000.
# Epoch finished ! Loss: 0.02017482279334217
# Starting epoch 212/4000.
# Epoch finished ! Loss: 0.020534855115693064
# Starting epoch 213/4000.
# Epoch finished ! Loss: 0.01804082157323137
# Starting epoch 214/4000.
# Epoch finished ! Loss: 0.020087902341037987
# Starting epoch 215/4000.
# Epoch finished ! Loss: 0.018900468572974206
# Starting epoch 216/4000.
# Epoch finished ! Loss: 0.018768557440489532
# Starting epoch 217/4000.
# Epoch finished ! Loss: 0.02000754219479859
# Starting epoch 218/4000.
# Epoch finished ! Loss: 0.019552724540699274
# Starting epoch 219/4000.
# Epoch finished ! Loss: 0.019444606790784746
# Starting epoch 220/4000.
# Epoch finished ! Loss: 0.01770539883291349
# Starting epoch 221/4000.
# Epoch finished ! Loss: 0.019195273413788527
# Starting epoch 222/4000.
# Epoch finished ! Loss: 0.01827274700626731
# Starting epoch 223/4000.
# Epoch finished ! Loss: 0.02008813216816634
# Starting epoch 224/4000.
# Epoch finished ! Loss: 0.019107548822648823
# Starting epoch 225/4000.
# Epoch finished ! Loss: 0.020429271995089947
# Starting epoch 226/4000.
# Epoch finished ! Loss: 0.020150892133824528
# Starting epoch 227/4000.
# Epoch finished ! Loss: 0.018102506140712647
# Starting epoch 228/4000.
# Epoch finished ! Loss: 0.018927382945548743
# Starting epoch 229/4000.
# Epoch finished ! Loss: 0.018721032491885125
# Starting epoch 230/4000.
# Epoch finished ! Loss: 0.019647876685485243
# Starting epoch 231/4000.
# Epoch finished ! Loss: 0.01902391226030886
# Starting epoch 232/4000.
# Epoch finished ! Loss: 0.019769638148136436
# Starting epoch 233/4000.
# Epoch finished ! Loss: 0.020230079774046318
# Starting epoch 234/4000.
# Epoch finished ! Loss: 0.020411706902086733
# Starting epoch 235/4000.
# Epoch finished ! Loss: 0.019423446734435856
# Starting epoch 236/4000.
# Epoch finished ! Loss: 0.019685994565952568
# Starting epoch 237/4000.
# Epoch finished ! Loss: 0.01898513047490269
# Starting epoch 238/4000.
# Epoch finished ! Loss: 0.019793609029147775
# Starting epoch 239/4000.
# Epoch finished ! Loss: 0.019968535657972096
# Starting epoch 240/4000.
# Epoch finished ! Loss: 0.019519821950234474
# Starting epoch 241/4000.
# Epoch finished ! Loss: 0.018195443612057716
# Starting epoch 242/4000.
# Epoch finished ! Loss: 0.019149908015970142
# Starting epoch 243/4000.
# Epoch finished ! Loss: 0.018444285925943403
# Starting epoch 244/4000.
# Epoch finished ! Loss: 0.01871605966007337
# Starting epoch 245/4000.
# Epoch finished ! Loss: 0.019269630732014775
# Starting epoch 246/4000.
# Epoch finished ! Loss: 0.017892095958814025
# Starting epoch 247/4000.
# Epoch finished ! Loss: 0.01817089932737872
# Starting epoch 248/4000.
# Epoch finished ! Loss: 0.020552623365074397
# Starting epoch 249/4000.
# Epoch finished ! Loss: 0.018849559500813483
# Starting epoch 250/4000.
# Epoch finished ! Loss: 0.018419055338017642
# Starting epoch 251/4000.
# Epoch finished ! Loss: 0.018314186274074017
# Starting epoch 252/4000.
# Epoch finished ! Loss: 0.019524218165315688
# Starting epoch 253/4000.
# Epoch finished ! Loss: 0.01863446618663147
# Starting epoch 254/4000.
# Epoch finished ! Loss: 0.01833842492196709
# Starting epoch 255/4000.
# Epoch finished ! Loss: 0.019492346327751875
# Starting epoch 256/4000.
# Epoch finished ! Loss: 0.018941402644850315
# Starting epoch 257/4000.
# Epoch finished ! Loss: 0.0189248142298311
# Starting epoch 258/4000.
# Epoch finished ! Loss: 0.018918421864509583
# Starting epoch 259/4000.
# Epoch finished ! Loss: 0.01696202519815415
# Starting epoch 260/4000.
# Epoch finished ! Loss: 0.017952765617519618
# Starting epoch 261/4000.
# Epoch finished ! Loss: 0.017739533784333617
# Starting epoch 262/4000.
# Epoch finished ! Loss: 0.019200661696959286
# Starting epoch 263/4000.
# Epoch finished ! Loss: 0.020643466524779795
# Starting epoch 264/4000.
# Epoch finished ! Loss: 0.018929330399259925
# Starting epoch 265/4000.
# Epoch finished ! Loss: 0.01871553882956505
# Starting epoch 266/4000.
# Epoch finished ! Loss: 0.01885621407418512
# Starting epoch 267/4000.
# Epoch finished ! Loss: 0.018964202667120844
# Starting epoch 268/4000.
# Epoch finished ! Loss: 0.017899830359965563
# Starting epoch 269/4000.
# Epoch finished ! Loss: 0.01852397995535284
# Starting epoch 270/4000.
# Epoch finished ! Loss: 0.018358931271359326
# Starting epoch 271/4000.
# Epoch finished ! Loss: 0.02038891289848834
# Starting epoch 272/4000.
# Epoch finished ! Loss: 0.016570319689344616
# Starting epoch 273/4000.
# Epoch finished ! Loss: 0.018222403363324702
# Starting epoch 274/4000.
# Epoch finished ! Loss: 0.018214148189872503
# Starting epoch 275/4000.
# Epoch finished ! Loss: 0.017594205494970084
# Starting epoch 276/4000.
# Epoch finished ! Loss: 0.018834435660392047
# Starting epoch 277/4000.
# Epoch finished ! Loss: 0.019031484425067902
# Starting epoch 278/4000.
# Epoch finished ! Loss: 0.019890516600571572
# Starting epoch 279/4000.
# Epoch finished ! Loss: 0.018170355726033448
# Starting epoch 280/4000.
# Epoch finished ! Loss: 0.01843185634352267
# Starting epoch 281/4000.
# Epoch finished ! Loss: 0.01937679322436452
# Starting epoch 282/4000.
# Epoch finished ! Loss: 0.019436568988021465
# Starting epoch 283/4000.
# Epoch finished ! Loss: 0.018831293995026498
# Starting epoch 284/4000.
# Epoch finished ! Loss: 0.01857882416807115
# Starting epoch 285/4000.
# Epoch finished ! Loss: 0.018373216083273292
# Starting epoch 286/4000.
# Epoch finished ! Loss: 0.017384270625188946
# Starting epoch 287/4000.
# Epoch finished ! Loss: 0.018070589296985417
# Starting epoch 288/4000.
# Epoch finished ! Loss: 0.019305036740843207
# Starting epoch 289/4000.
# Epoch finished ! Loss: 0.019216103584039957
# Starting epoch 290/4000.
# Epoch finished ! Loss: 0.01950432297307998
# Starting epoch 291/4000.
# Epoch finished ! Loss: 0.018979076656978577
# Starting epoch 292/4000.
# Epoch finished ! Loss: 0.019786110578570514
# Starting epoch 293/4000.
# Epoch finished ! Loss: 0.01948422788409516
# Starting epoch 294/4000.
# Epoch finished ! Loss: 0.01838253882015124
# Starting epoch 295/4000.
# Epoch finished ! Loss: 0.02022837076801807
# Starting epoch 296/4000.
# Epoch finished ! Loss: 0.01849351651035249
# Starting epoch 297/4000.
# Epoch finished ! Loss: 0.01901192246004939
# Starting epoch 298/4000.
# Epoch finished ! Loss: 0.0192205777624622
# Starting epoch 299/4000.
# Epoch finished ! Loss: 0.01973837458062917
# Starting epoch 300/4000.
# Epoch finished ! Loss: 0.0194630742771551
# Starting epoch 301/4000.
# Epoch finished ! Loss: 0.020334545883815735
# Starting epoch 302/4000.
# Epoch finished ! Loss: 0.01910381035413593
# Starting epoch 303/4000.
# Epoch finished ! Loss: 0.018453859095461666
# Starting epoch 304/4000.
# Epoch finished ! Loss: 0.019375823740847408
# Starting epoch 305/4000.
# Epoch finished ! Loss: 0.018406288966070862
# Starting epoch 306/4000.
# Epoch finished ! Loss: 0.017806831595953553
# Starting epoch 307/4000.
# Epoch finished ! Loss: 0.017558529740199447
# Starting epoch 308/4000.
# Epoch finished ! Loss: 0.019600959203671664
# Starting epoch 309/4000.
# Epoch finished ! Loss: 0.019318811874836684
# Starting epoch 310/4000.
# Epoch finished ! Loss: 0.01928340255981311
# Starting epoch 311/4000.
# Epoch finished ! Loss: 0.01722026614006609
# Starting epoch 312/4000.
# Epoch finished ! Loss: 0.019568393775261938
# Starting epoch 313/4000.
# Epoch finished ! Loss: 0.018715608958154918
# Starting epoch 314/4000.
# Epoch finished ! Loss: 0.01991292997263372
# Starting epoch 315/4000.
# Epoch finished ! Loss: 0.01913935395423323
# Starting epoch 316/4000.
# Epoch finished ! Loss: 0.01934996711788699
# Starting epoch 317/4000.
# Epoch finished ! Loss: 0.01758815802168101
# Starting epoch 318/4000.
# Epoch finished ! Loss: 0.020208445261232555
# Starting epoch 319/4000.
# Epoch finished ! Loss: 0.019114859541878103
# Starting epoch 320/4000.
# Epoch finished ! Loss: 0.01953705375781283
# Starting epoch 321/4000.
# Epoch finished ! Loss: 0.02023133428301662
# Starting epoch 322/4000.
# Epoch finished ! Loss: 0.020225218567065894
# Starting epoch 323/4000.
# Epoch finished ! Loss: 0.02003834240604192
# Starting epoch 324/4000.
# Epoch finished ! Loss: 0.017266044404823332
# Starting epoch 325/4000.
# Epoch finished ! Loss: 0.019153993506915868
# Starting epoch 326/4000.
# Epoch finished ! Loss: 0.01845596208004281
# Starting epoch 327/4000.
# Epoch finished ! Loss: 0.02026658405084163
# Starting epoch 328/4000.
# Epoch finished ! Loss: 0.019135407428257166
# Starting epoch 329/4000.
# Epoch finished ! Loss: 0.018653195630759
# Starting epoch 330/4000.
# Epoch finished ! Loss: 0.01927991631673649
# Starting epoch 331/4000.
# Epoch finished ! Loss: 0.01814533381257206
# Starting epoch 332/4000.
# Epoch finished ! Loss: 0.020155259524472058
# Starting epoch 333/4000.
# Epoch finished ! Loss: 0.019543312373571098
# Starting epoch 334/4000.
# Epoch finished ! Loss: 0.01864938691724092
# Starting epoch 335/4000.
# Epoch finished ! Loss: 0.017783237784169615
# Starting epoch 336/4000.
# Epoch finished ! Loss: 0.01877467354061082
# Starting epoch 337/4000.
# Epoch finished ! Loss: 0.018874258757568894
# Starting epoch 338/4000.
# Epoch finished ! Loss: 0.01844565400388092
# Starting epoch 339/4000.
# Epoch finished ! Loss: 0.019353814620990305
# Starting epoch 340/4000.
# Epoch finished ! Loss: 0.01909822180168703
# Starting epoch 341/4000.
# Epoch finished ! Loss: 0.019364422420039773
# Starting epoch 342/4000.
# Epoch finished ! Loss: 0.017974473850335924
# Starting epoch 343/4000.
# Epoch finished ! Loss: 0.017797701084055005
# Starting epoch 344/4000.
# Epoch finished ! Loss: 0.019057103130035103
# Starting epoch 345/4000.
# Epoch finished ! Loss: 0.019584591756574808
# Starting epoch 346/4000.
# Epoch finished ! Loss: 0.02042250809026882
# Starting epoch 347/4000.
# Epoch finished ! Loss: 0.017908265272853895
# Starting epoch 348/4000.
# Epoch finished ! Loss: 0.017421027133241295
# Starting epoch 349/4000.
# Epoch finished ! Loss: 0.01885901126079261
# Starting epoch 350/4000.
# Epoch finished ! Loss: 0.01891284289304167
# Starting epoch 351/4000.
# Epoch finished ! Loss: 0.019441005133558065
# Starting epoch 352/4000.
# Epoch finished ! Loss: 0.020672231761272995
# Starting epoch 353/4000.
# Epoch finished ! Loss: 0.018608195020351558
# Starting epoch 354/4000.
# Epoch finished ! Loss: 0.01854841932654381
# Starting epoch 355/4000.
# Epoch finished ! Loss: 0.018351002188865095
# Starting epoch 356/4000.
# Epoch finished ! Loss: 0.019738064508419483
# Starting epoch 357/4000.
# Epoch finished ! Loss: 0.017532426014076917
# Starting epoch 358/4000.
# Epoch finished ! Loss: 0.019561992271337657
# Starting epoch 359/4000.
# Epoch finished ! Loss: 0.017895040137227626
# Starting epoch 360/4000.
# Epoch finished ! Loss: 0.019237645552493632
# Starting epoch 361/4000.
# Epoch finished ! Loss: 0.01902681348146871
# Starting epoch 362/4000.
# Epoch finished ! Loss: 0.019307514443062244
# Starting epoch 363/4000.
# Epoch finished ! Loss: 0.018064879043959082
# Starting epoch 364/4000.
# Epoch finished ! Loss: 0.018866487534251065
# Starting epoch 365/4000.
# Epoch finished ! Loss: 0.02001419060397893
# Starting epoch 366/4000.
# Epoch finished ! Loss: 0.019355735171120613
# Starting epoch 367/4000.
# Epoch finished ! Loss: 0.017772503849118947
# Starting epoch 368/4000.
# Epoch finished ! Loss: 0.018239059089682996
# Starting epoch 369/4000.
# Epoch finished ! Loss: 0.019407858909107744
# Starting epoch 370/4000.
# Epoch finished ! Loss: 0.018441657139919698
# Starting epoch 371/4000.
# Epoch finished ! Loss: 0.019100418756715955
# Starting epoch 372/4000.
# Epoch finished ! Loss: 0.018810968624893575
# Starting epoch 373/4000.
# Epoch finished ! Loss: 0.018468586762901397
# Starting epoch 374/4000.
# Epoch finished ! Loss: 0.017336116661317645
# Starting epoch 375/4000.
# Epoch finished ! Loss: 0.01958663170225918
# Starting epoch 376/4000.
# Epoch finished ! Loss: 0.01871903776191175
# Starting epoch 377/4000.
# Epoch finished ! Loss: 0.019585428468417376
# Starting epoch 378/4000.
# Epoch finished ! Loss: 0.017789245978929103
# Starting epoch 379/4000.
# Epoch finished ! Loss: 0.01784654522780329
# Starting epoch 380/4000.
# Epoch finished ! Loss: 0.018129464134108274
# Starting epoch 381/4000.
# Epoch finished ! Loss: 0.01695878877071664
# Starting epoch 382/4000.
# Epoch finished ! Loss: 0.01787460466148332
# Starting epoch 383/4000.
# Epoch finished ! Loss: 0.019132247543893754
# Starting epoch 384/4000.
# Epoch finished ! Loss: 0.01881164968945086
# Starting epoch 385/4000.
# Epoch finished ! Loss: 0.01809193785302341
# Starting epoch 386/4000.
# Epoch finished ! Loss: 0.018156825797632337
# Starting epoch 387/4000.
# Epoch finished ! Loss: 0.01896553400438279
# Starting epoch 388/4000.
# Epoch finished ! Loss: 0.01798661252250895
# Starting epoch 389/4000.
# Epoch finished ! Loss: 0.019759806885849683
# Starting epoch 390/4000.
# Epoch finished ! Loss: 0.01843027677386999
# Starting epoch 391/4000.
# Epoch finished ! Loss: 0.018135879561305045
# Starting epoch 392/4000.
# Epoch finished ! Loss: 0.018302024982403964
# Starting epoch 393/4000.
# Epoch finished ! Loss: 0.01793824239866808
# Starting epoch 394/4000.
# Epoch finished ! Loss: 0.019818428030703217
# Starting epoch 395/4000.
# Epoch finished ! Loss: 0.01845516647445038
# Starting epoch 396/4000.
# Epoch finished ! Loss: 0.017492465546820313
# Starting epoch 397/4000.
# Epoch finished ! Loss: 0.01799914319999516
# Starting epoch 398/4000.
# Epoch finished ! Loss: 0.018309242965187877
# Starting epoch 399/4000.
# Epoch finished ! Loss: 0.018830848846118898
# Starting epoch 400/4000.
# Epoch finished ! Loss: 0.018820349697489292
# Starting epoch 401/4000.
# Epoch finished ! Loss: 0.018329433584585785
# Starting epoch 402/4000.
# Epoch finished ! Loss: 0.01818207560572773
# Starting epoch 403/4000.
# Epoch finished ! Loss: 0.01886233719997108
# Starting epoch 404/4000.
# Epoch finished ! Loss: 0.018218455684836952
# Starting epoch 405/4000.
# Epoch finished ! Loss: 0.017797134106513113
# Starting epoch 406/4000.
# Epoch finished ! Loss: 0.018555170169565826
# Starting epoch 407/4000.
# Epoch finished ! Loss: 0.017910797742661088
# Starting epoch 408/4000.
# Epoch finished ! Loss: 0.017466396535746755
# Starting epoch 409/4000.
# Epoch finished ! Loss: 0.01780801882268861
# Starting epoch 410/4000.
# Epoch finished ! Loss: 0.017943025031127036
# Starting epoch 411/4000.
# Epoch finished ! Loss: 0.018814304284751414
# Starting epoch 412/4000.
# Epoch finished ! Loss: 0.018834964535199106
# Starting epoch 413/4000.
# Epoch finished ! Loss: 0.018276874674484134
# Starting epoch 414/4000.
# Epoch finished ! Loss: 0.019752304116263986
# Starting epoch 415/4000.
# Epoch finished ! Loss: 0.01767290058778599
# Starting epoch 416/4000.
# Epoch finished ! Loss: 0.017880462505854667
# Starting epoch 417/4000.
# Epoch finished ! Loss: 0.017427342035807668
# Starting epoch 418/4000.
# Epoch finished ! Loss: 0.018774134188424794
# Starting epoch 419/4000.
# Epoch finished ! Loss: 0.017876100062858315
# Starting epoch 420/4000.
# Epoch finished ! Loss: 0.018526615330483765
# Starting epoch 421/4000.
# Epoch finished ! Loss: 0.017883588175754993
# Starting epoch 422/4000.
# Epoch finished ! Loss: 0.019214858906343578
# Starting epoch 423/4000.
# Epoch finished ! Loss: 0.017326072906143963
# Starting epoch 424/4000.
# Epoch finished ! Loss: 0.01795532730175182
# Starting epoch 425/4000.
# Epoch finished ! Loss: 0.017589146271348
# Starting epoch 426/4000.
# Epoch finished ! Loss: 0.01909015589626506
# Starting epoch 427/4000.
# Epoch finished ! Loss: 0.01830852823331952
# Starting epoch 428/4000.
# Epoch finished ! Loss: 0.018073835968971254
# Starting epoch 429/4000.
# Epoch finished ! Loss: 0.017245047818869354
# Starting epoch 430/4000.
# Epoch finished ! Loss: 0.017447042162530124
# Starting epoch 431/4000.
# Epoch finished ! Loss: 0.01888995066983625
# Starting epoch 432/4000.
# Epoch finished ! Loss: 0.016977473837323488
# Starting epoch 433/4000.
# Epoch finished ! Loss: 0.018335609801579267
# Starting epoch 434/4000.
# Epoch finished ! Loss: 0.01877752833534032
# Starting epoch 435/4000.
# Epoch finished ! Loss: 0.019279287836980075
# Starting epoch 436/4000.
# Epoch finished ! Loss: 0.018726752314250916
# Starting epoch 437/4000.
# Epoch finished ! Loss: 0.016926992882508783
# Starting epoch 438/4000.
# Epoch finished ! Loss: 0.016879478155169637
# Starting epoch 439/4000.
# Epoch finished ! Loss: 0.019063993461895735
# Starting epoch 440/4000.
# Epoch finished ! Loss: 0.017939962504897267
# Starting epoch 441/4000.
# Epoch finished ! Loss: 0.01647670306265354
# Starting epoch 442/4000.
# Epoch finished ! Loss: 0.017540413280948998
# Starting epoch 443/4000.
# Epoch finished ! Loss: 0.01753010315587744
# Starting epoch 444/4000.
# Epoch finished ! Loss: 0.017030081211123614
# Starting epoch 445/4000.
# Epoch finished ! Loss: 0.017276402632705867
# Starting epoch 446/4000.
# Epoch finished ! Loss: 0.01737841028952971
# Starting epoch 447/4000.
# Epoch finished ! Loss: 0.018494824296794832
# Starting epoch 448/4000.
# Epoch finished ! Loss: 0.017718761670403184
# Starting epoch 449/4000.
# Epoch finished ! Loss: 0.017873731290455906
# Starting epoch 450/4000.
# Epoch finished ! Loss: 0.018625770695507526
# Starting epoch 451/4000.
# Epoch finished ! Loss: 0.01704068521503359
# Starting epoch 452/4000.
# Epoch finished ! Loss: 0.016642478457652033
# Starting epoch 453/4000.
# Epoch finished ! Loss: 0.017391320609021932
# Starting epoch 454/4000.
# Epoch finished ! Loss: 0.016994429100304843
# Starting epoch 455/4000.
# Epoch finished ! Loss: 0.01655917103635147
# Starting epoch 456/4000.
# Epoch finished ! Loss: 0.017063226376194507
# Starting epoch 457/4000.
# Epoch finished ! Loss: 0.01721177132567391
# Starting epoch 458/4000.
# Epoch finished ! Loss: 0.01717753706034273
# Starting epoch 459/4000.
# Epoch finished ! Loss: 0.01710715137887746
# Starting epoch 460/4000.
# Epoch finished ! Loss: 0.01678992100059986
# Starting epoch 461/4000.
# Epoch finished ! Loss: 0.01690881170798093
# Starting epoch 462/4000.
# Epoch finished ! Loss: 0.01817970327101648
# Starting epoch 463/4000.
# Epoch finished ! Loss: 0.016296670032897965
# Starting epoch 464/4000.
# Epoch finished ! Loss: 0.015215457486920058
# Starting epoch 465/4000.
# Epoch finished ! Loss: 0.017245651967823506
# Starting epoch 466/4000.
# Epoch finished ! Loss: 0.016696632641833277
# Starting epoch 467/4000.
# Epoch finished ! Loss: 0.01744969324208796
# Starting epoch 468/4000.
# Epoch finished ! Loss: 0.016974600893445314
# Starting epoch 469/4000.
# Epoch finished ! Loss: 0.01562945421319455
# Starting epoch 470/4000.
# Epoch finished ! Loss: 0.01702404422685504
# Starting epoch 471/4000.
# Epoch finished ! Loss: 0.016218718816526236
# Starting epoch 472/4000.
# Epoch finished ! Loss: 0.016582482936792077
# Starting epoch 473/4000.
# Epoch finished ! Loss: 0.0164483372005634
# Starting epoch 474/4000.
# Epoch finished ! Loss: 0.01687436462379992
# Starting epoch 475/4000.
# Epoch finished ! Loss: 0.015377559466287494
# Starting epoch 476/4000.
# Epoch finished ! Loss: 0.0170326306251809
# Starting epoch 477/4000.
# Epoch finished ! Loss: 0.01711937175132334
# Starting epoch 478/4000.
# Epoch finished ! Loss: 0.016827651706989855
# Starting epoch 479/4000.
# Epoch finished ! Loss: 0.017019641655497252
# Starting epoch 480/4000.
# Epoch finished ! Loss: 0.017063576995860787
# Starting epoch 481/4000.
# Epoch finished ! Loss: 0.016085113410372286
# Starting epoch 482/4000.
# Epoch finished ! Loss: 0.016783660592045634
# Starting epoch 483/4000.
# Epoch finished ! Loss: 0.017744511947967112
# Starting epoch 484/4000.
# Epoch finished ! Loss: 0.016406583099160342
# Starting epoch 485/4000.
# Epoch finished ! Loss: 0.01682877573184669
# Starting epoch 486/4000.
# Epoch finished ! Loss: 0.017167076072655617
# Starting epoch 487/4000.
# Epoch finished ! Loss: 0.016879612777847795
# Starting epoch 488/4000.
# Epoch finished ! Loss: 0.01689248954644427
# Starting epoch 489/4000.
# Epoch finished ! Loss: 0.015540538588538766
# Starting epoch 490/4000.
# Epoch finished ! Loss: 0.017565648618619888
# Starting epoch 491/4000.
# Epoch finished ! Loss: 0.015679398784413934
# Starting epoch 492/4000.
# Epoch finished ! Loss: 0.017079961486160755
# Starting epoch 493/4000.
# Epoch finished ! Loss: 0.016912903543561696
# Starting epoch 494/4000.
# Epoch finished ! Loss: 0.017161218856927007
# Starting epoch 495/4000.
# Epoch finished ! Loss: 0.01564009819412604
# Starting epoch 496/4000.
# Epoch finished ! Loss: 0.016809373162686825
# Starting epoch 497/4000.
# Epoch finished ! Loss: 0.016878581838682294
# Starting epoch 498/4000.
# Epoch finished ! Loss: 0.015366777288727462
# Starting epoch 499/4000.
# Epoch finished ! Loss: 0.016353375604376198
# Starting epoch 500/4000.
# Epoch finished ! Loss: 0.01702985616866499
# Starting epoch 501/4000.
# Epoch finished ! Loss: 0.01565943791065365
# Starting epoch 502/4000.
# Epoch finished ! Loss: 0.016610330913681536
# Starting epoch 503/4000.
# Epoch finished ! Loss: 0.0161908820271492
# Starting epoch 504/4000.
# Epoch finished ! Loss: 0.017144765215925874
# Starting epoch 505/4000.
# Epoch finished ! Loss: 0.017085455707274377
# Starting epoch 506/4000.
# Epoch finished ! Loss: 0.01705662379972637
# Starting epoch 507/4000.
# Epoch finished ! Loss: 0.015657961275428532
# Starting epoch 508/4000.
# Epoch finished ! Loss: 0.015932139416690916
# Starting epoch 509/4000.
# Epoch finished ! Loss: 0.015908141899853945
# Starting epoch 510/4000.
# Epoch finished ! Loss: 0.016557796311099084
# Starting epoch 511/4000.
# Epoch finished ! Loss: 0.016325780365150422
# Starting epoch 512/4000.
# Epoch finished ! Loss: 0.016230900899972766
# Starting epoch 513/4000.
# Epoch finished ! Loss: 0.01602928841020912
# Starting epoch 514/4000.
# Epoch finished ! Loss: 0.015806742839049547
# Starting epoch 515/4000.
# Epoch finished ! Loss: 0.016052634594962
# Starting epoch 516/4000.
# Epoch finished ! Loss: 0.01589817473432049
# Starting epoch 517/4000.
# Epoch finished ! Loss: 0.01617147703655064
# Starting epoch 518/4000.
# Epoch finished ! Loss: 0.016762885567732155
# Starting epoch 519/4000.
# Epoch finished ! Loss: 0.016430522256996483
# Starting epoch 520/4000.
# Epoch finished ! Loss: 0.015879507106728852
# Starting epoch 521/4000.
# Epoch finished ! Loss: 0.01527618815889582
# Starting epoch 522/4000.
# Epoch finished ! Loss: 0.01578726073494181
# Starting epoch 523/4000.
# Epoch finished ! Loss: 0.015556736302096396
# Starting epoch 524/4000.
# Epoch finished ! Loss: 0.01512122807907872
# Starting epoch 525/4000.
# Epoch finished ! Loss: 0.017491005663760006
# Starting epoch 526/4000.
# Epoch finished ! Loss: 0.016198585764504968
# Starting epoch 527/4000.
# Epoch finished ! Loss: 0.016223383171018214
# Starting epoch 528/4000.
# Epoch finished ! Loss: 0.016980009770486505
# Starting epoch 529/4000.
# Epoch finished ! Loss: 0.016606374795082958
# Starting epoch 530/4000.
# Epoch finished ! Loss: 0.01682054284028709
# Starting epoch 531/4000.
# Epoch finished ! Loss: 0.016543617437127976
# Starting epoch 532/4000.
# Epoch finished ! Loss: 0.015875854471232742
# Starting epoch 533/4000.
# Epoch finished ! Loss: 0.016516657173633577
# Starting epoch 534/4000.
# Epoch finished ! Loss: 0.015667232545092703
# Starting epoch 535/4000.
# Epoch finished ! Loss: 0.015580704750027508
# Starting epoch 536/4000.
# Epoch finished ! Loss: 0.01626939666457474
# Starting epoch 537/4000.
# Epoch finished ! Loss: 0.01692143961554393
# Starting epoch 538/4000.
# Epoch finished ! Loss: 0.01652682143030688
# Starting epoch 539/4000.
# Epoch finished ! Loss: 0.01667384341126308
# Starting epoch 540/4000.
# Epoch finished ! Loss: 0.016561547201126813
# Starting epoch 541/4000.
# Epoch finished ! Loss: 0.01579223311273381
# Starting epoch 542/4000.
# Epoch finished ! Loss: 0.015537646249867976
# Starting epoch 543/4000.
# Epoch finished ! Loss: 0.01567235612310469
# Starting epoch 544/4000.
# Epoch finished ! Loss: 0.015970489801838995
# Starting epoch 545/4000.
# Epoch finished ! Loss: 0.01611402870621532
# Starting epoch 546/4000.
# Epoch finished ! Loss: 0.0154341422021389
# Starting epoch 547/4000.
# Epoch finished ! Loss: 0.01599490427179262
# Starting epoch 548/4000.
# Epoch finished ! Loss: 0.016281586862169205
# Starting epoch 549/4000.
# Epoch finished ! Loss: 0.015377641061786563
# Starting epoch 550/4000.
# Epoch finished ! Loss: 0.01593210347928107
# Starting epoch 551/4000.
# Epoch finished ! Loss: 0.017103978106752037
# Starting epoch 552/4000.
# Epoch finished ! Loss: 0.014736066572368145
# Starting epoch 553/4000.
# Epoch finished ! Loss: 0.016076134564355016
# Starting epoch 554/4000.
# Epoch finished ! Loss: 0.016368392028380186
# Starting epoch 555/4000.
# Epoch finished ! Loss: 0.01659322001505643
# Starting epoch 556/4000.
# Epoch finished ! Loss: 0.015129266073927283
# Starting epoch 557/4000.
# Epoch finished ! Loss: 0.015605648886412382
# Starting epoch 558/4000.
# Epoch finished ! Loss: 0.015638682048302145
# Starting epoch 559/4000.
# Epoch finished ! Loss: 0.017861507879570127
# Starting epoch 560/4000.
# Epoch finished ! Loss: 0.016119103238452226
# Starting epoch 561/4000.
# Epoch finished ! Loss: 0.01620500653516501
# Starting epoch 562/4000.
# Epoch finished ! Loss: 0.01755180526524782
# Starting epoch 563/4000.
# Epoch finished ! Loss: 0.016844842687714846
# Starting epoch 564/4000.
# Epoch finished ! Loss: 0.016319158091209828
# Starting epoch 565/4000.
# Epoch finished ! Loss: 0.015802191488910468
# Starting epoch 566/4000.
# Epoch finished ! Loss: 0.016834629944059997
# Starting epoch 567/4000.
# Epoch finished ! Loss: 0.015959867823403327
# Starting epoch 568/4000.
# Epoch finished ! Loss: 0.015711894386913627
# Starting epoch 569/4000.
# Epoch finished ! Loss: 0.015630180086009204
# Starting epoch 570/4000.
# Epoch finished ! Loss: 0.016516837407834828
# Starting epoch 571/4000.
# Epoch finished ! Loss: 0.01570137954549864
# Starting epoch 572/4000.
# Epoch finished ! Loss: 0.015643715858459473
# Starting epoch 573/4000.
# Epoch finished ! Loss: 0.01613412471488118
# Starting epoch 574/4000.
# Epoch finished ! Loss: 0.01595161996083334
# Starting epoch 575/4000.
# Epoch finished ! Loss: 0.016037610499188303
# Starting epoch 576/4000.
# Epoch finished ! Loss: 0.01591468610567972
# Starting epoch 577/4000.
# Epoch finished ! Loss: 0.016882657667156308
# Starting epoch 578/4000.
# Epoch finished ! Loss: 0.016418688709381967
# Starting epoch 579/4000.
# Epoch finished ! Loss: 0.01722567912656814
# Starting epoch 580/4000.
# Epoch finished ! Loss: 0.016114683647174388
# Starting epoch 581/4000.
# Epoch finished ! Loss: 0.015794675739016384
# Starting epoch 582/4000.
# Epoch finished ! Loss: 0.01644231769023463
# Starting epoch 583/4000.
# Epoch finished ! Loss: 0.01544182535726577
# Starting epoch 584/4000.
# Epoch finished ! Loss: 0.016453404491767288
# Starting epoch 585/4000.
# Epoch finished ! Loss: 0.017912202270235867
# Starting epoch 586/4000.
# Epoch finished ! Loss: 0.016748722014017402
# Starting epoch 587/4000.
# Epoch finished ! Loss: 0.016243436047807334
# Starting epoch 588/4000.
# Epoch finished ! Loss: 0.01648319121450186
# Starting epoch 589/4000.
# Epoch finished ! Loss: 0.016142799356020986
# Starting epoch 590/4000.
# Epoch finished ! Loss: 0.016694714897312224
# Starting epoch 591/4000.
# Epoch finished ! Loss: 0.015660977934021502
# Starting epoch 592/4000.
# Epoch finished ! Loss: 0.015485739894211292
# Starting epoch 593/4000.
# Epoch finished ! Loss: 0.016808399464935064
# Starting epoch 594/4000.
# Epoch finished ! Loss: 0.01632930024061352
# Starting epoch 595/4000.
# Epoch finished ! Loss: 0.016734274302143602
# Starting epoch 596/4000.
# Epoch finished ! Loss: 0.016521166427992284
# Starting epoch 597/4000.
# Epoch finished ! Loss: 0.015689650364220143
# Starting epoch 598/4000.
# Epoch finished ! Loss: 0.016630029212683438
# Starting epoch 599/4000.
# Epoch finished ! Loss: 0.01652677103411406
# Starting epoch 600/4000.
# Epoch finished ! Loss: 0.015605280094314366
# Starting epoch 601/4000.
# Epoch finished ! Loss: 0.016381095664110036
# Starting epoch 602/4000.
# Epoch finished ! Loss: 0.015622284344863147
# Starting epoch 603/4000.
# Epoch finished ! Loss: 0.01626053781947121
# Starting epoch 604/4000.
# Epoch finished ! Loss: 0.016029326338320972
# Starting epoch 605/4000.
# Epoch finished ! Loss: 0.01606747875921428
# Starting epoch 606/4000.
# Epoch finished ! Loss: 0.0164550949819386
# Starting epoch 607/4000.
# Epoch finished ! Loss: 0.0162869913270697
# Starting epoch 608/4000.
# Epoch finished ! Loss: 0.016924833552911876
# Starting epoch 609/4000.
# Epoch finished ! Loss: 0.016617010894697158
# Starting epoch 610/4000.
# Epoch finished ! Loss: 0.01682340889237821
# Starting epoch 611/4000.
# Epoch finished ! Loss: 0.015584672219119966
# Starting epoch 612/4000.
# Epoch finished ! Loss: 0.016432605613954366
# Starting epoch 613/4000.
# Epoch finished ! Loss: 0.016280151158571243
# Starting epoch 614/4000.
# Epoch finished ! Loss: 0.014936839661095292
# Starting epoch 615/4000.
# Epoch finished ! Loss: 0.014912414585705847
# Starting epoch 616/4000.
# Epoch finished ! Loss: 0.016319797351025046
# Starting epoch 617/4000.
# Epoch finished ! Loss: 0.015435997722670436
# Starting epoch 618/4000.
# Epoch finished ! Loss: 0.017144494934473186
# Starting epoch 619/4000.
# Epoch finished ! Loss: 0.01575756665552035
# Starting epoch 620/4000.
# Epoch finished ! Loss: 0.016233741829637438
# Starting epoch 621/4000.
# Epoch finished ! Loss: 0.015669699979480357
# Starting epoch 622/4000.
# Epoch finished ! Loss: 0.01575244227424264
# Starting epoch 623/4000.
# Epoch finished ! Loss: 0.016913590917829423
# Starting epoch 624/4000.
# Epoch finished ! Loss: 0.016211496503092348
# Starting epoch 625/4000.
# Epoch finished ! Loss: 0.01634994006017223
# Starting epoch 626/4000.
# Epoch finished ! Loss: 0.015842300176154823
# Starting epoch 627/4000.
# Epoch finished ! Loss: 0.01629549718927592
# Starting epoch 628/4000.
# Epoch finished ! Loss: 0.01636388461338356
# Starting epoch 629/4000.
# Epoch finished ! Loss: 0.015556844812817872
# Starting epoch 630/4000.
# Epoch finished ! Loss: 0.016085054993163796
# Starting epoch 631/4000.
# Epoch finished ! Loss: 0.01553076874697581
# Starting epoch 632/4000.
# Epoch finished ! Loss: 0.016692358965519814
# Starting epoch 633/4000.
# Epoch finished ! Loss: 0.01750262436689809
# Starting epoch 634/4000.
# Epoch finished ! Loss: 0.017622915108222514
# Starting epoch 635/4000.
# Epoch finished ! Loss: 0.016827389900572597
# Starting epoch 636/4000.
# Epoch finished ! Loss: 0.0167649504262954
# Starting epoch 637/4000.
# Epoch finished ! Loss: 0.016163304762449114
# Starting epoch 638/4000.
# Epoch finished ! Loss: 0.015723259001970292
# Starting epoch 639/4000.
# Epoch finished ! Loss: 0.01597744380123913
# Starting epoch 640/4000.
# Epoch finished ! Loss: 0.015240504371467978
# Starting epoch 641/4000.
# Epoch finished ! Loss: 0.015095723187550902
# Starting epoch 642/4000.
# Epoch finished ! Loss: 0.01610880926018581
# Starting epoch 643/4000.
# Epoch finished ! Loss: 0.01644029140006751
# Starting epoch 644/4000.
# Epoch finished ! Loss: 0.015918394643813373
# Starting epoch 645/4000.
# Epoch finished ! Loss: 0.017353920941241087
# Starting epoch 646/4000.
# Epoch finished ! Loss: 0.01527480068616569
# Starting epoch 647/4000.
# Epoch finished ! Loss: 0.016799693775828926
# Starting epoch 648/4000.
# Epoch finished ! Loss: 0.016246392298489808
# Starting epoch 649/4000.
# Epoch finished ! Loss: 0.015950098156463356
# Starting epoch 650/4000.
# Epoch finished ! Loss: 0.015788479708135128
# Starting epoch 651/4000.
# Epoch finished ! Loss: 0.01598579790443182
# Starting epoch 652/4000.
# Epoch finished ! Loss: 0.015191181469708681
# Starting epoch 653/4000.
# Epoch finished ! Loss: 0.016742027876898647
# Starting epoch 654/4000.
# Epoch finished ! Loss: 0.01515730667160824
# Starting epoch 655/4000.
# Epoch finished ! Loss: 0.01630999067565426
# Starting epoch 656/4000.
# Epoch finished ! Loss: 0.01610591934295371
# Starting epoch 657/4000.
# Epoch finished ! Loss: 0.01620528323110193
# Starting epoch 658/4000.
# Epoch finished ! Loss: 0.016070047195535155
# Starting epoch 659/4000.
# Epoch finished ! Loss: 0.016051351418718697
# Starting epoch 660/4000.
# Epoch finished ! Loss: 0.016266370879020543
# Starting epoch 661/4000.
# Epoch finished ! Loss: 0.015520316909532993
# Starting epoch 662/4000.
# Epoch finished ! Loss: 0.016432244435418398
# Starting epoch 663/4000.
# Epoch finished ! Loss: 0.01712985128397122
# Starting epoch 664/4000.
# Epoch finished ! Loss: 0.016348868468776347
# Starting epoch 665/4000.
# Epoch finished ! Loss: 0.01635340980719775
# Starting epoch 666/4000.
# Epoch finished ! Loss: 0.016749088233336807
# Starting epoch 667/4000.
# Epoch finished ! Loss: 0.016658156376797705
# Starting epoch 668/4000.
# Epoch finished ! Loss: 0.016224336985033005
# Starting epoch 669/4000.
# Epoch finished ! Loss: 0.015581716364249588
# Starting epoch 670/4000.
# Epoch finished ! Loss: 0.015228022122755647
# Starting epoch 671/4000.
# Epoch finished ! Loss: 0.015937588398810477
# Starting epoch 672/4000.
# Epoch finished ! Loss: 0.016092750092502682
# Starting epoch 673/4000.
# Epoch finished ! Loss: 0.01619614502415061
# Starting epoch 674/4000.
# Epoch finished ! Loss: 0.01650020226370543
# Starting epoch 675/4000.
# Epoch finished ! Loss: 0.01599618203472346
# Starting epoch 676/4000.
# Epoch finished ! Loss: 0.01576099133817479
# Starting epoch 677/4000.
# Epoch finished ! Loss: 0.01618696467485279
# Starting epoch 678/4000.
# Epoch finished ! Loss: 0.01580168560612947
# Starting epoch 679/4000.
# Epoch finished ! Loss: 0.01602529364172369
# Starting epoch 680/4000.
# Epoch finished ! Loss: 0.017644705588463695
# Starting epoch 681/4000.
# Epoch finished ! Loss: 0.015033104148460551
# Starting epoch 682/4000.
# Epoch finished ! Loss: 0.01610123524442315
# Starting epoch 683/4000.
# Epoch finished ! Loss: 0.015933952864725143
# Starting epoch 684/4000.
# Epoch finished ! Loss: 0.016661778511479496
# Starting epoch 685/4000.
# Epoch finished ! Loss: 0.01620447722962126
# Starting epoch 686/4000.
# Epoch finished ! Loss: 0.016376747039612383
# Starting epoch 687/4000.
# Epoch finished ! Loss: 0.01545856734737754
# Starting epoch 688/4000.
# Epoch finished ! Loss: 0.016944702167529614
# Starting epoch 689/4000.
# Epoch finished ! Loss: 0.01581210867734626
# Starting epoch 690/4000.
# Epoch finished ! Loss: 0.016176396457012743
# Starting epoch 691/4000.
# Epoch finished ! Loss: 0.016182013630168513
# Starting epoch 692/4000.
# Epoch finished ! Loss: 0.01581460612360388
# Starting epoch 693/4000.
# Epoch finished ! Loss: 0.01582701054867357
# ...
# Starting epoch 2441/4000.
# Epoch finished ! Loss: 0.015977872465737165
# Starting epoch 2442/4000.
# Epoch finished ! Loss: 0.01662105709547177
# Starting epoch 2443/4000.
# Epoch finished ! Loss: 0.015126113698352128
# Starting epoch 2444/4000.
# Epoch finished ! Loss: 0.014996052731294184
# Starting epoch 2445/4000.
# Epoch finished ! Loss: 0.015046744991559535
# Starting epoch 2446/4000.
# Epoch finished ! Loss: 0.014431752741802483
# Starting epoch 2447/4000.
# Epoch finished ! Loss: 0.015823127166368068
# Starting epoch 2448/4000.
# Epoch finished ! Loss: 0.015422020899131894
# Starting epoch 2449/4000.
# Epoch finished ! Loss: 0.015284960623830557
# Starting epoch 2450/4000.
# Epoch finished ! Loss: 0.015143300814088434
# Starting epoch 2451/4000.
# Epoch finished ! Loss: 0.015710655669681727
# Starting epoch 2452/4000.
# Epoch finished ! Loss: 0.0153060432523489
# Starting epoch 2453/4000.
# Epoch finished ! Loss: 0.015217750892043113
# Starting epoch 2454/4000.
# Epoch finished ! Loss: 0.015999064745847134
# Starting epoch 2455/4000.
# Epoch finished ! Loss: 0.015266799042001367
# Starting epoch 2456/4000.
# Epoch finished ! Loss: 0.016078592115081846
# Starting epoch 2457/4000.
# Epoch finished ! Loss: 0.01646642670966685
# Starting epoch 2458/4000.
# Epoch finished ! Loss: 0.01570061150705442
# Starting epoch 2459/4000.
# Epoch finished ! Loss: 0.014966927003115416
# Starting epoch 2460/4000.
# Epoch finished ! Loss: 0.0157431960105896
# Starting epoch 2461/4000.
# Epoch finished ! Loss: 0.015779054269660264
# Starting epoch 2462/4000.
# Epoch finished ! Loss: 0.015530351304914803
# Starting epoch 2463/4000.
# Epoch finished ! Loss: 0.01563551704166457
# Starting epoch 2464/4000.
# Epoch finished ! Loss: 0.015030277683399618
# Starting epoch 2465/4000.
# Epoch finished ! Loss: 0.016105469886679203
# Starting epoch 2466/4000.
# Epoch finished ! Loss: 0.013908352388534695
# Starting epoch 2467/4000.
# Epoch finished ! Loss: 0.01531362822279334
# Starting epoch 2468/4000.
# Epoch finished ! Loss: 0.015341420425102115
# Starting epoch 2469/4000.
# Epoch finished ! Loss: 0.01531326494878158
# Starting epoch 2470/4000.
# Epoch finished ! Loss: 0.015343886043410748
# Starting epoch 2471/4000.
# Epoch finished ! Loss: 0.014470107876695693
# Starting epoch 2472/4000.
# Epoch finished ! Loss: 0.016276667756028474
# Starting epoch 2473/4000.
# Epoch finished ! Loss: 0.015361640474293382
# Starting epoch 2474/4000.
# Epoch finished ! Loss: 0.015041780832689255
# Starting epoch 2475/4000.
# Epoch finished ! Loss: 0.016202167875599117
# Starting epoch 2476/4000.
# Epoch finished ! Loss: 0.01623338550562039
# Starting epoch 2477/4000.
# Epoch finished ! Loss: 0.01544705629348755
# Starting epoch 2478/4000.
# Epoch finished ! Loss: 0.01569734130753204
# Starting epoch 2479/4000.
# Epoch finished ! Loss: 0.015089164837263525
# Starting epoch 2480/4000.
# Epoch finished ! Loss: 0.015334999049082398
# Starting epoch 2481/4000.
# Epoch finished ! Loss: 0.015832175163086503
# Starting epoch 2482/4000.
# Epoch finished ! Loss: 0.014776977931614966
# Starting epoch 2483/4000.
# Epoch finished ! Loss: 0.01415344006381929
# Starting epoch 2484/4000.
# Epoch finished ! Loss: 0.01614196883747354
# Starting epoch 2485/4000.
# Epoch finished ! Loss: 0.015987824962940066
# Starting epoch 2486/4000.
# Epoch finished ! Loss: 0.015389949025120586
# Starting epoch 2487/4000.
# Epoch finished ! Loss: 0.014866905706003308
# Starting epoch 2488/4000.
# Epoch finished ! Loss: 0.01458948579384014
# Starting epoch 2489/4000.
# Epoch finished ! Loss: 0.01433847836451605
# Starting epoch 2490/4000.
# Epoch finished ! Loss: 0.015066296025179327
# Starting epoch 2491/4000.
# Epoch finished ! Loss: 0.015065731527283788
# Starting epoch 2492/4000.
# Epoch finished ! Loss: 0.014796925522387028
# Starting epoch 2493/4000.
# Epoch finished ! Loss: 0.0151463603368029
# Starting epoch 2494/4000.
# Epoch finished ! Loss: 0.01569471468683332
# Starting epoch 2495/4000.
# Epoch finished ! Loss: 0.01471483294153586
# Starting epoch 2496/4000.
# Epoch finished ! Loss: 0.0140613570692949
# Starting epoch 2497/4000.
# Epoch finished ! Loss: 0.015338224917650222
# Starting epoch 2498/4000.
# Epoch finished ! Loss: 0.015791677858214826
# Starting epoch 2499/4000.
# Epoch finished ! Loss: 0.015183188673108815
# Starting epoch 2500/4000.
# Epoch finished ! Loss: 0.015257185627706348
# Starting epoch 2501/4000.
# Epoch finished ! Loss: 0.015079198242165148
# Starting epoch 2502/4000.
# Epoch finished ! Loss: 0.015249409072566777
# Starting epoch 2503/4000.
# Epoch finished ! Loss: 0.014904992748051881
# Starting epoch 2504/4000.
# Epoch finished ! Loss: 0.01683612884953618
# Starting epoch 2505/4000.
# Epoch finished ! Loss: 0.014513105060905218
# Starting epoch 2506/4000.
# Epoch finished ! Loss: 0.01543431639438495
# Starting epoch 2507/4000.
# Epoch finished ! Loss: 0.01505452535348013
# Starting epoch 2508/4000.
# Epoch finished ! Loss: 0.014781522809062152
# Starting epoch 2509/4000.
# Epoch finished ! Loss: 0.0157718924456276
# Starting epoch 2510/4000.
# Epoch finished ! Loss: 0.015243373322300613
# Starting epoch 2511/4000.
# Epoch finished ! Loss: 0.015379466174636036
# Starting epoch 2512/4000.
# Epoch finished ! Loss: 0.015879326243884863
# Starting epoch 2513/4000.
# Epoch finished ! Loss: 0.015319400955922902
# Starting epoch 2514/4000.
# Epoch finished ! Loss: 0.01554314597742632
# Starting epoch 2515/4000.
# Epoch finished ! Loss: 0.014947042020503431
# Starting epoch 2516/4000.
# Epoch finished ! Loss: 0.015285396506078542
# Starting epoch 2517/4000.
# Epoch finished ! Loss: 0.015228211367502808
# Starting epoch 2518/4000.
# Epoch finished ! Loss: 0.015936138643883168
# Starting epoch 2519/4000.
# Epoch finished ! Loss: 0.015323990071192384
# Starting epoch 2520/4000.
# Epoch finished ! Loss: 0.015236053091939539
# Starting epoch 2521/4000.
# Epoch finished ! Loss: 0.015566129691433162
# Starting epoch 2522/4000.
# Epoch finished ! Loss: 0.015954979578964412
# Starting epoch 2523/4000.
# Epoch finished ! Loss: 0.015140843798872084
# Starting epoch 2524/4000.
# Epoch finished ! Loss: 0.015067597094457597
# Starting epoch 2525/4000.
# Epoch finished ! Loss: 0.015255210688337684
# Starting epoch 2526/4000.
# Epoch finished ! Loss: 0.014767118217423558
# Starting epoch 2527/4000.
# Epoch finished ! Loss: 0.016130666760727764
# Starting epoch 2528/4000.
# Epoch finished ! Loss: 0.015165334288030862
# Starting epoch 2529/4000.
# Epoch finished ! Loss: 0.01610674341209233
# Starting epoch 2530/4000.
# Epoch finished ! Loss: 0.015111168613657355
# Starting epoch 2531/4000.
# Epoch finished ! Loss: 0.014937969460152089
# Starting epoch 2532/4000.
# Epoch finished ! Loss: 0.01581842094892636
# Starting epoch 2533/4000.
# Epoch finished ! Loss: 0.015578339982312173
# Starting epoch 2534/4000.
# Epoch finished ! Loss: 0.015115890745073557
# Starting epoch 2535/4000.
# Epoch finished ! Loss: 0.015487097634468228
# Starting epoch 2536/4000.
# Epoch finished ! Loss: 0.016118790896143764
# Starting epoch 2537/4000.
# Epoch finished ! Loss: 0.015282819571439177
# Starting epoch 2538/4000.
# Epoch finished ! Loss: 0.014451269793789833
# Starting epoch 2539/4000.
# Epoch finished ! Loss: 0.015628756757359953
# Starting epoch 2540/4000.
# Epoch finished ! Loss: 0.014796378655591979
# Starting epoch 2541/4000.
# Epoch finished ! Loss: 0.014966182631906123
# Starting epoch 2542/4000.
# Epoch finished ! Loss: 0.01496753164101392
# Starting epoch 2543/4000.
# Epoch finished ! Loss: 0.014426272339187562
# Starting epoch 2544/4000.
# Epoch finished ! Loss: 0.015385913068894298
# Starting epoch 2545/4000.
# Epoch finished ! Loss: 0.015153246105182917
# Starting epoch 2546/4000.
# Epoch finished ! Loss: 0.014799826761009171
# Starting epoch 2547/4000.
# Epoch finished ! Loss: 0.01570134018547833
# Starting epoch 2548/4000.
# Epoch finished ! Loss: 0.015521987131796778
# Starting epoch 2549/4000.
# Epoch finished ! Loss: 0.01434697761433199
# Starting epoch 2550/4000.
# Epoch finished ! Loss: 0.01531481829006225
# Starting epoch 2551/4000.
# Epoch finished ! Loss: 0.016125864430796354
# Starting epoch 2552/4000.
# Epoch finished ! Loss: 0.01472444604150951
# Starting epoch 2553/4000.
# Epoch finished ! Loss: 0.015617129078600555
# Starting epoch 2554/4000.
# Epoch finished ! Loss: 0.015299271617550403
# Starting epoch 2555/4000.
# Epoch finished ! Loss: 0.0144374888157472
# Starting epoch 2556/4000.
# Epoch finished ! Loss: 0.01470926778856665
# Starting epoch 2557/4000.
# Epoch finished ! Loss: 0.014994767971802502
# Starting epoch 2558/4000.
# Epoch finished ! Loss: 0.015331615949980915
# Starting epoch 2559/4000.
# Epoch finished ! Loss: 0.014858924900181592
# Starting epoch 2560/4000.
# Epoch finished ! Loss: 0.015375377691816539
# Starting epoch 2561/4000.
# Epoch finished ! Loss: 0.01514152658637613
# Starting epoch 2562/4000.
# Epoch finished ! Loss: 0.01506261290051043
# Starting epoch 2563/4000.
# Epoch finished ! Loss: 0.015043859113939106
# Starting epoch 2564/4000.
# Epoch finished ! Loss: 0.015537178318481892
# Starting epoch 2565/4000.
# Epoch finished ! Loss: 0.015760581218637527
# Starting epoch 2566/4000.
# Epoch finished ! Loss: 0.014471732184756548
# Starting epoch 2567/4000.
# Epoch finished ! Loss: 0.015046934736892581
# Starting epoch 2568/4000.
# Epoch finished ! Loss: 0.015410698798950762
# Starting epoch 2569/4000.
# Epoch finished ! Loss: 0.0145126486197114
# Starting epoch 2570/4000.
# Epoch finished ! Loss: 0.015916832070797683
# Starting epoch 2571/4000.
# Epoch finished ! Loss: 0.015870626852847635
# Starting epoch 2572/4000.
# Epoch finished ! Loss: 0.015234741615131497
# Starting epoch 2573/4000.
# Epoch finished ! Loss: 0.015662896190769972
# Starting epoch 2574/4000.
# Epoch finished ! Loss: 0.015887393068987878
# Starting epoch 2575/4000.
# Epoch finished ! Loss: 0.015994415420573206
# Starting epoch 2576/4000.
# Epoch finished ! Loss: 0.014789377071429044
# Starting epoch 2577/4000.
# Epoch finished ! Loss: 0.015773240569978954
# Starting epoch 2578/4000.
# Epoch finished ! Loss: 0.015285024722106754
# Starting epoch 2579/4000.
# Epoch finished ! Loss: 0.015391776000615209
# Starting epoch 2580/4000.
# Epoch finished ! Loss: 0.01676733265630901
# Starting epoch 2581/4000.
# Epoch finished ! Loss: 0.015632960386574267
# Starting epoch 2582/4000.
# Epoch finished ! Loss: 0.016175395739264787
# Starting epoch 2583/4000.
# Epoch finished ! Loss: 0.01570718928705901
# Starting epoch 2584/4000.
# Epoch finished ! Loss: 0.014410611882340163
# Starting epoch 2585/4000.
# Epoch finished ! Loss: 0.014787329395767301
# Starting epoch 2586/4000.
# Epoch finished ! Loss: 0.015810737176798283
# Starting epoch 2587/4000.
# Epoch finished ! Loss: 0.016122934489976613
# Starting epoch 2588/4000.
# Epoch finished ! Loss: 0.01608483070740476
# Starting epoch 2589/4000.
# Epoch finished ! Loss: 0.013668920483905823
# Starting epoch 2590/4000.
# Epoch finished ! Loss: 0.015370718005578965
# Starting epoch 2591/4000.
# Epoch finished ! Loss: 0.01595252288971096
# Starting epoch 2592/4000.
# Epoch finished ! Loss: 0.014208539691753685
# Starting epoch 2593/4000.
# Epoch finished ! Loss: 0.015263600065372885
# Starting epoch 2594/4000.
# Epoch finished ! Loss: 0.015185504057444631
# Starting epoch 2595/4000.
# Epoch finished ! Loss: 0.015031665621791035
# Starting epoch 2596/4000.
# Epoch finished ! Loss: 0.015105128497816622
# Starting epoch 2597/4000.
# Epoch finished ! Loss: 0.015829072683118284
# Starting epoch 2598/4000.
# Epoch finished ! Loss: 0.015163650619797409
# Starting epoch 2599/4000.
# Epoch finished ! Loss: 0.014792056113947183
# Starting epoch 2600/4000.
# Epoch finished ! Loss: 0.015458103257697076
# Starting epoch 2601/4000.
# Epoch finished ! Loss: 0.015371694683562965
# Starting epoch 2602/4000.
# Epoch finished ! Loss: 0.014661541185341775
# Starting epoch 2603/4000.
# Epoch finished ! Loss: 0.01576866179239005
# Starting epoch 2604/4000.
# Epoch finished ! Loss: 0.014959460427053272
# Starting epoch 2605/4000.
# Epoch finished ! Loss: 0.014492474345024675
# Starting epoch 2606/4000.
# Epoch finished ! Loss: 0.016064043319784106
# Starting epoch 2607/4000.
# Epoch finished ! Loss: 0.01549514919752255
# Starting epoch 2608/4000.
# Epoch finished ! Loss: 0.015091569675132633
# Starting epoch 2609/4000.
# Epoch finished ! Loss: 0.015228431136347354
# Starting epoch 2610/4000.
# Epoch finished ! Loss: 0.015357888641301543
# Starting epoch 2611/4000.
# Epoch finished ! Loss: 0.016045731003396214
# Starting epoch 2612/4000.
# Epoch finished ! Loss: 0.014744448149576784
# Starting epoch 2613/4000.
# Epoch finished ! Loss: 0.015288063685875385
# Starting epoch 2614/4000.
# Epoch finished ! Loss: 0.015366823808290065
# Starting epoch 2615/4000.
# Epoch finished ! Loss: 0.01576511557213962
# Starting epoch 2616/4000.
# Epoch finished ! Loss: 0.01404972147429362
# Starting epoch 2617/4000.
# Epoch finished ! Loss: 0.015908778330776842
# Starting epoch 2618/4000.
# Epoch finished ! Loss: 0.014283477352000773
# Starting epoch 2619/4000.
# Epoch finished ! Loss: 0.01527911180164665
# Starting epoch 2620/4000.
# Epoch finished ! Loss: 0.01585986256832257
# Starting epoch 2621/4000.
# Epoch finished ! Loss: 0.014371758315246553
# Starting epoch 2622/4000.
# Epoch finished ! Loss: 0.01591038638725877
# Starting epoch 2623/4000.
# Epoch finished ! Loss: 0.014686023711692541
# Starting epoch 2624/4000.
# Epoch finished ! Loss: 0.015388512494973838
# Starting epoch 2625/4000.
# Epoch finished ! Loss: 0.014690470322966576
# Starting epoch 2626/4000.
# Epoch finished ! Loss: 0.014529076823964714
# Starting epoch 2627/4000.
# Epoch finished ! Loss: 0.014758236811030657
# Starting epoch 2628/4000.
# Epoch finished ! Loss: 0.014519248122815043
# Starting epoch 2629/4000.
# Epoch finished ! Loss: 0.015944201475940646
# Starting epoch 2630/4000.
# Epoch finished ! Loss: 0.01515475775813684
# Starting epoch 2631/4000.
# Epoch finished ! Loss: 0.015621658670715988
# Starting epoch 2632/4000.
# Epoch finished ! Loss: 0.015331971965497359
# Starting epoch 2633/4000.
# Epoch finished ! Loss: 0.015388376265764236
# Starting epoch 2634/4000.
# Epoch finished ! Loss: 0.015031745098531247
# Starting epoch 2635/4000.
# Epoch finished ! Loss: 0.01560416049323976
# Starting epoch 2636/4000.
# Epoch finished ! Loss: 0.015596257022116334
# Starting epoch 2637/4000.
# Epoch finished ! Loss: 0.01585609557805583
# Starting epoch 2638/4000.
# Epoch finished ! Loss: 0.015073995594866574
# Starting epoch 2639/4000.
# Epoch finished ! Loss: 0.01621956176823005
# Starting epoch 2640/4000.
# Epoch finished ! Loss: 0.015168987843208016
# Starting epoch 2641/4000.
# Epoch finished ! Loss: 0.01537254509748891
# Starting epoch 2642/4000.
# Epoch finished ! Loss: 0.016520466562360524
# Starting epoch 2643/4000.
# Epoch finished ! Loss: 0.015393062785733491
# Starting epoch 2644/4000.
# Epoch finished ! Loss: 0.01606175840133801
# Starting epoch 2645/4000.
# Epoch finished ! Loss: 0.01543424294795841
# Starting epoch 2646/4000.
# Epoch finished ! Loss: 0.016782276821322738
# Starting epoch 2647/4000.
# Epoch finished ! Loss: 0.014868310128804296
# Starting epoch 2648/4000.
# Epoch finished ! Loss: 0.016454184148460626
# Starting epoch 2649/4000.
# Epoch finished ! Loss: 0.015363849815912545
# Starting epoch 2650/4000.
# Epoch finished ! Loss: 0.016607258201111107
# Starting epoch 2651/4000.
# Epoch finished ! Loss: 0.01602042493177578
# Starting epoch 2652/4000.
# Epoch finished ! Loss: 0.014962929661851376
# Starting epoch 2653/4000.
# Epoch finished ! Loss: 0.01663292513694614
# Starting epoch 2654/4000.
# Epoch finished ! Loss: 0.015554560627788306
# Starting epoch 2655/4000.
# Epoch finished ! Loss: 0.01578079842729494
# Starting epoch 2656/4000.
# Epoch finished ! Loss: 0.014646963286213576
# Starting epoch 2657/4000.
# Epoch finished ! Loss: 0.015190374932717531
# Starting epoch 2658/4000.
# Epoch finished ! Loss: 0.015336087881587445
# Starting epoch 2659/4000.
# Epoch finished ! Loss: 0.015120895090512931
# Starting epoch 2660/4000.
# Epoch finished ! Loss: 0.015910506155341862
# Starting epoch 2661/4000.
# Epoch finished ! Loss: 0.01558598248520866
# Starting epoch 2662/4000.
# Epoch finished ! Loss: 0.01477692365879193
# Starting epoch 2663/4000.
# Epoch finished ! Loss: 0.014475994184613228
# Starting epoch 2664/4000.
# Epoch finished ! Loss: 0.015194282308220864
# Starting epoch 2665/4000.
# Epoch finished ! Loss: 0.014945538737811149
# Starting epoch 2666/4000.
# Epoch finished ! Loss: 0.015348455077037216
# Starting epoch 2667/4000.
# Epoch finished ! Loss: 0.01591179098468274
# Starting epoch 2668/4000.
# Epoch finished ! Loss: 0.014841646200511604
# Starting epoch 2669/4000.
# Epoch finished ! Loss: 0.016855186014436186
# Starting epoch 2670/4000.

# %%
if os.path.isdir(model_save_path):
            torch.save(model.state_dict(),model_save_path + 'sony{}.pth'.format(epoch + 1))
else:
    os.makedirs(model_save_path, exist_ok=True)
    torch.save(model.state_dict(),model_save_path + 'sony{}.pth'.format(epoch + 1))
